# %% [markdown]
# ### Bootstrap Feature Imporatance Computation for Institutional Claims Medicaid Model.
# - This notebook captures the steps involved in computing feature importance scores across 500 cross-validation folds.
# - Further this notebook also holds the information on the number of times a feature was ranked higher than noise variable - for both numerical and categorical features data.

# %%
# Importing the required libraries
import os
import sys
import warnings
import numpy as np
import pandas as pd

warnings.filterwarnings("ignore")

# %%
# Adding dependency python files to sys path
sys.path[1:1] = ["/home/ec2-user/SageMaker/GitHub Repos/cipy/cipy/"]
sys.path[2:2] = ["/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/"]
sys.path[3:3] = ["/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/02_feat_sel_and_imp/"]
sys.path[4:4] = ["/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/02_feat_sel_and_imp/institutional_claims/02_step"]

sys.path
# Out:
# ['/home/ec2-user/SageMaker/envs/wqp_env/lib/python3.6',
#  '/home/ec2-user/SageMaker/GitHub Repos/cipy/cipy/',
#  '/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/',
#  '/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/02_feat_sel_and_imp/',
#  '/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/02_feat_sel_and_imp/institutional_claims/02_step',
#  '',
#  '/home/ec2-user/SageMaker/envs/wqp_env/lib/python3.6/site-packages',
#  '/home/ec2-user/SageMaker/envs/wqp_env/lib/python3.6/lib-dynload',
#  '/home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6',
#  '/home/ec2-user/SageMaker/envs/wqp_env/lib/python3.6/site-packages/IPython/extensions',
#  '/home/ec2-user/.ipython']

# %%
# Importing methods from wqp_methods path file, especially get_cvfolds will be leveraged in this notebook.
from wqp_methods import *

# %%
# Importing BootStrapFeatImp class for computing Feature Importance Scores
from bootstrap_feat_imp import BootstrapFeatImp

# %%
# Reading the Institutional claims dataset
ref_col= "claim_filing_ind_code3"

# csv_path for Institutional Claims Data Path
csv_path = "/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/01_data_preprocessing/preprocessed_datasets/"

# Loading the institutional claims dataset into inst_claims
inst_claims = pd.read_csv(csv_path+"ic_preprocessed_dataset_2021-06-06.csv")

# Creating the event_flag - for survival analysis.
inst_claims["event_flag"] = True

# %%
final_cat_cols = ['Description_OccurrenceInformation_1',
 'Description_OccurrenceInformation_2',
 'HCPCSCode_Medicine_Services_and_Procedures',
 'HCPCSCode_Pathology_and_Laboratory_Procedures',
 'HCPCSCode_Surgery',
 'RevCode_Emergency_Room',
 'RevCode_Laboratory',
 'RevCode_Medical/Surgical_Supplies_and_Devices',
 'RevCode_Operating_Room_Services',
 'RevCode_Other_Imaging_Services',
 'RevCode_Pharmacy',
 'RevCode_Pharmacy_-_Extension_of_025X',
 'RevCode_Physical_Therapy',
 'RevCode_Radiology_Diagnostic',
 'admission_source_code',
 'admission_type_code',
 'ccsr_category_1_code_ExternalCauseOfInjury_HI_1',
 'ccsr_category_1_code_OtherDiagnosisInformation_HI_1',
 'ccsr_category_1_code_OtherDiagnosisInformation_HI_2',
 'ccsr_category_1_code_OtherDiagnosisInformation_HI_3',
 'ccsr_category_1_code_Patient’SReasonForVisit_1',
 'ccsr_category_1_code_PrincipalDiagnosis_1',
 'claim_creation_hour',
 'claim_creation_weekday',
 'claim_freq_type_code',
 'claim_has_admission_dthr',
 'claim_has_operating_physician_id',
 'claim_has_payer_claim_control_number',
 'claim_has_referring_provider_id',
 'other_hcpcscodes',
 'other_ndccodes',
 'other_revcodes',
 'payer_name',
 'payer_resp_seq_num',
 'subscriber_city',
 'subscriber_gender',
 'subscriber_pat_gender']

# %%
# Load the feature information after preprocessing - 01 Notebook output
filtered_columns_data = pickl("/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/02_feat_sel_and_imp/institutional_claims/02_step/inst_claims_cat_num_filtered_feature_details.pickle")

# Derive Final Model Features for..
claim_filing_indicator_code = "Medicaid"
    
# Retrieving claim_filing_indicator_code specific data
cfic_df = inst_claims[inst_claims[ref_col]==claim_filing_indicator_code].reset_index()

# Clipping the response_time values as per claim_filing_indicator_code specific percentiles
cfic_df = clip_right_tail2(cfic_df, 0.98)

# Creating the structured array with event_flag and response_time values.
y = Surv.from_arrays(cfic_df["event_flag"].values, cfic_df["response_time"].values)

# Retrieving categorical features..
cat_cols = final_cat_cols#filtered_columns_data[claim_filing_indicator_code]["final_cat_cols"]
cat_df = cfic_df[cat_cols]

# Combining 'RevCode_Pharmacy' & 'RevCode_Pharmacy_-_Extension_of_025X'
mask1 = cat_df["RevCode_Pharmacy_-_Extension_of_025X"] == "Yes"
cat_df.loc[mask1, "RevCode_Pharmacy"] = "Yes"
del cat_df["RevCode_Pharmacy_-_Extension_of_025X"]

# Encoding categorical features..
le = LabelEncoder()
encoded_cat_df = cat_df.apply(lambda col: le.fit_transform(col.astype(str)), axis=0, result_type="expand")

# Adding noise variable for categorical data
np.random.seed(0)
encoded_cat_df["noise"] = np.random.poisson(5, size=len(encoded_cat_df))

# Retrieving numerical features..
num_cols = filtered_columns_data[claim_filing_indicator_code]["final_num_cols"]
num_df = cfic_df[num_cols]

# Adding noise variable for numerical data
np.random.seed(0)
num_df["noise"] = np.random.normal(0, 1, len(num_df))

# %%
cv_folds = []

if os.path.isfile("inst_medicaid_cv_folds.pickle"):
    cv_folds=pickl("inst_medicaid_cv_folds.pickle")

else:
    for i in range(50):
        cv_folds += get_folds(cfic_df)
        
    pickl("inst_medicaid_cv_folds.pickle", cv_folds)
# Out:
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3836 418 6.1005 6.1005 418 0
# 1 3864 390 5.7974 5.7974 390 0
# 2 3838 416 6.0841 6.0841 416 0
# 3 3809 445 6.6135 6.6135 445 0
# 4 3784 470 6.6 6.6 470 0
# 5 3799 455 6.1165 6.1165 455 0
# 6 3804 450 7.2711 7.2711 450 0
# 7 3860 394 7.0761 7.0761 394 0
# 8 3861 393 6.7405 6.7405 393 0
# 9 3831 423 6.1442 6.1442 423 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3789 465 6.3763 6.3763 465 0
# 1 3839 415 5.9735 5.9735 415 0
# 2 3782 472 7.1949 7.1949 472 0
# 3 3846 408 6.4338 6.4338 408 0
# 4 3834 420 5.9214 5.9214 420 0
# 5 3831 423 6.2199 6.2199 423 0
# 6 3804 450 6.8756 6.8756 450 0
# 7 3832 422 6.0403 6.0403 422 0
# 8 3865 389 6.9306 6.9306 389 0
# 9 3864 390 6.5538 6.5538 390 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3832 422 6.0853 6.0853 422 0
# 1 3801 453 6.2252 6.2252 453 0
# 2 3844 410 6.1293 6.1293 410 0
# 3 3798 456 7.1645 7.1645 456 0
# 4 3828 426 7.6596 7.6596 426 0
# 5 3852 402 6.4328 6.4328 402 0
# 6 3832 422 6.1801 6.1801 422 0
# 7 3826 428 6.6145 6.6145 428 0
# 8 3889 365 6.137 6.137 365 0
# 9 3784 470 5.9191 5.9191 470 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3842 412 6.6675 6.6675 412 0
# 1 3803 451 6.102 6.102 451 0
# 2 3834 420 5.8143 5.8143 420 0
# 3 3876 378 7.0794 7.0794 378 0
# 4 3839 415 6.6313 6.6313 415 0
# 5 3775 479 6.5157 6.5157 479 0
# 6 3843 411 6.2311 6.2311 411 0
# 7 3802 452 6.4558 6.4558 452 0
# 8 3841 413 6.3148 6.3148 413 0
# 9 3831 423 6.8582 6.8582 423 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3816 438 6.3927 6.3927 438 0
# 1 3855 399 5.9148 5.9148 399 0
# 2 3815 439 6.8588 6.8588 439 0
# 3 3848 406 6.1897 6.1897 406 0
# 4 3812 442 6.6765 6.6765 442 0
# 5 3847 407 7.0393 7.0393 407 0
# 6 3828 426 5.9413 5.9413 426 0
# 7 3817 437 6.1144 6.1144 437 0
# 8 3808 446 6.9238 6.9238 446 0
# 9 3840 414 6.4903 6.4903 414 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3835 419 6.4081 6.4081 419 0
# 1 3854 400 6.4825 6.4825 400 0
# 2 3849 405 5.837 5.837 405 0
# 3 3820 434 6.8571 6.8571 434 0
# 4 3842 412 6.2767 6.2767 412 0
# 5 3827 427 6.2881 6.2881 427 0
# 6 3800 454 6.8458 6.8458 454 0
# 7 3817 437 6.5675 6.5675 437 0
# 8 3834 420 6.5024 6.5024 420 0
# 9 3808 446 6.4574 6.4574 446 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3845 409 6.1907 6.1907 409 0
# 1 3822 432 6.0648 6.0648 432 0
# 2 3832 422 6.9194 6.9194 422 0
# 3 3843 411 6.5961 6.5961 411 0
# 4 3817 437 6.1556 6.1556 437 0
# 5 3815 439 6.4784 6.4784 439 0
# 6 3769 485 7.4165 7.4165 485 0
# 7 3861 393 6.2494 6.2494 393 0
# 8 3846 408 6.3897 6.3897 408 0
# 9 3836 418 5.9833 5.9833 418 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3841 413 6.724 6.724 413 0
# 1 3849 405 6.2346 6.2346 405 0
# 2 3790 464 5.9052 5.9052 464 0
# 3 3825 429 5.7366 5.7366 429 0
# 4 3837 417 6.3525 6.3525 417 0
# 5 3822 432 6.9236 6.9236 432 0
# 6 3809 445 6.5955 6.5955 445 0
# 7 3846 408 6.4583 6.4583 408 0
# 8 3890 364 7.5797 7.5797 364 0
# 9 3777 477 6.3019 6.3019 477 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3816 438 6.0776 6.0776 438 0
# 1 3876 378 6.4339 6.4339 378 0
# 2 3825 429 6.5571 6.5571 429 0
# 3 3819 435 6.9816 6.9816 435 0
# 4 3844 410 6.1634 6.1634 410 0
# 5 3832 422 6.0 6.0 422 0
# 6 3819 435 6.7563 6.7563 435 0
# 7 3811 443 6.2235 6.2235 443 0
# 8 3835 419 6.7589 6.7589 419 0
# 9 3809 445 6.6225 6.6225 445 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3847 407 6.6314 6.6314 407 0
# 1 3835 419 5.9881 5.9881 419 0
# 2 3819 435 6.2575 6.2575 435 0
# 3 3793 461 7.2191 7.2191 461 0
# 4 3870 384 6.5286 6.5286 384 0
# 5 3831 423 6.0426 6.0426 423 0
# 6 3832 422 6.7062 6.7062 422 0
# 7 3805 449 6.2494 6.2494 449 0
# 8 3821 433 6.7436 6.7436 433 0
# 9 3833 421 6.1781 6.1781 421 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3834 420 5.95 5.95 420 0
# 1 3829 425 7.0588 7.0588 425 0
# 2 3823 431 6.2227 6.2227 431 0
# 3 3768 486 7.0082 7.0082 486 0
# 4 3858 396 6.7828 6.7828 396 0
# 5 3840 414 5.8696 5.8696 414 0
# 6 3850 404 6.4678 6.4678 404 0
# 7 3861 393 6.5802 6.5802 393 0
# 8 3810 444 6.0991 6.0991 444 0
# 9 3813 441 6.5034 6.5034 441 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3823 431 6.7146 6.7146 431 0
# 1 3851 403 6.0893 6.0893 403 0
# 2 3826 428 6.5818 6.5818 428 0
# 3 3831 423 5.8203 5.8203 423 0
# 4 3819 435 6.7724 6.7724 435 0
# 5 3869 385 6.1117 6.1117 385 0
# 6 3824 430 7.1116 7.1116 430 0
# 7 3842 412 5.8956 5.8956 412 0
# 8 3767 487 6.6037 6.6037 487 0
# 9 3834 420 6.7833 6.7833 420 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3832 422 5.8294 5.8294 422 0
# 1 3838 416 6.274 6.274 416 0
# 2 3824 430 5.8674 5.8674 430 0
# 3 3790 464 7.2716 7.2716 464 0
# 4 3857 397 5.7809 5.7809 397 0
# 5 3860 394 6.5736 6.5736 394 0
# 6 3832 422 7.3057 7.3057 422 0
# 7 3840 414 6.6473 6.6473 414 0
# 8 3834 420 6.2714 6.2714 420 0
# 9 3779 475 6.6463 6.6463 475 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3795 459 5.7277 5.7277 459 0
# 1 3843 411 6.2993 6.2993 411 0
# 2 3836 418 6.8445 6.8445 418 0
# 3 3819 435 6.377 6.377 435 0
# 4 3807 447 6.1298 6.1298 447 0
# 5 3841 413 6.2324 6.2324 413 0
# 6 3852 402 7.3035 7.3035 402 0
# 7 3832 422 5.5498 5.5498 422 0
# 8 3844 410 6.8561 6.8561 410 0
# 9 3817 437 7.373 7.373 437 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3845 409 5.9438 5.9438 409 0
# 1 3835 419 6.8305 6.8305 419 0
# 2 3822 432 6.2546 6.2546 432 0
# 3 3785 469 6.2878 6.2878 469 0
# 4 3818 436 6.2661 6.2661 436 0
# 5 3846 408 6.4804 6.4804 408 0
# 6 3817 437 6.8764 6.8764 437 0
# 7 3802 452 6.4712 6.4712 452 0
# 8 3852 402 7.092 7.092 402 0
# 9 3864 390 6.0949 6.0949 390 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3762 492 6.7642 6.7642 492 0
# 1 3827 427 6.7564 6.7564 427 0
# 2 3814 440 6.4386 6.4386 440 0
# 3 3829 425 6.3035 6.3035 425 0
# 4 3818 436 6.6972 6.6972 436 0
# 5 3847 407 5.8428 5.8428 407 0
# 6 3866 388 6.1237 6.1237 388 0
# 7 3812 442 6.4661 6.4661 442 0
# 8 3835 419 6.895 6.895 419 0
# 9 3876 378 6.1693 6.1693 378 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3822 432 6.0394 6.0394 432 0
# 1 3808 446 6.3229 6.3229 446 0
# 2 3844 410 6.1146 6.1146 410 0
# 3 3838 416 6.7067 6.7067 416 0
# 4 3835 419 6.3174 6.3174 419 0
# 5 3847 407 6.285 6.285 407 0
# 6 3813 441 6.6395 6.6395 441 0
# 7 3855 399 6.6942 6.6942 399 0
# 8 3826 428 7.3855 7.3855 428 0
# 9 3798 456 6.1118 6.1118 456 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3825 429 5.7366 5.7366 429 0
# 1 3871 383 6.8747 6.8747 383 0
# 2 3827 427 5.9532 5.9532 427 0
# 3 3811 443 6.6817 6.6817 443 0
# 4 3806 448 6.1295 6.1295 448 0
# 5 3831 423 5.3877 5.3877 423 0
# 6 3811 443 7.4808 7.4808 443 0
# 7 3848 406 6.7094 6.7094 406 0
# 8 3849 405 7.0988 7.0988 405 0
# 9 3807 447 6.5861 6.5861 447 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3801 453 5.9051 5.9051 453 0
# 1 3819 435 6.2828 6.2828 435 0
# 2 3836 418 6.5407 6.5407 418 0
# 3 3832 422 6.872 6.872 422 0
# 4 3827 427 6.8431 6.8431 427 0
# 5 3833 421 6.7126 6.7126 421 0
# 6 3829 425 5.9671 5.9671 425 0
# 7 3840 414 6.3744 6.3744 414 0
# 8 3836 418 6.933 6.933 418 0
# 9 3833 421 6.2114 6.2114 421 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3823 431 6.0998 6.0998 431 0
# 1 3804 450 5.9778 5.9778 450 0
# 2 3828 426 6.6737 6.6737 426 0
# 3 3804 450 7.3089 7.3089 450 0
# 4 3839 415 6.7036 6.7036 415 0
# 5 3847 407 5.9042 5.9042 407 0
# 6 3825 429 6.8392 6.8392 429 0
# 7 3863 391 5.9386 5.9386 391 0
# 8 3807 447 6.6085 6.6085 447 0
# 9 3846 408 6.451 6.451 408 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3823 431 6.6659 6.6659 431 0
# 1 3783 471 6.1401 6.1401 471 0
# 2 3824 430 6.5651 6.5651 430 0
# 3 3831 423 6.7234 6.7234 423 0
# 4 3844 410 6.5732 6.5732 410 0
# 5 3825 429 6.4009 6.4009 429 0
# 6 3788 466 6.2382 6.2382 466 0
# 7 3854 400 6.225 6.225 400 0
# 8 3864 390 6.9026 6.9026 390 0
# 9 3850 404 6.2277 6.2277 404 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3857 397 6.1839 6.1839 397 0
# 1 3829 425 7.0047 7.0047 425 0
# 2 3847 407 6.2654 6.2654 407 0
# 3 3822 432 6.2361 6.2361 432 0
# 4 3779 475 6.3263 6.3263 475 0
# 5 3819 435 6.2851 6.2851 435 0
# 6 3834 420 5.5952 5.5952 420 0
# 7 3860 394 7.236 7.236 394 0
# 8 3810 444 6.4032 6.4032 444 0
# 9 3829 425 7.1035 7.1035 425 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3819 435 5.8069 5.8069 435 0
# 1 3839 415 6.2506 6.2506 415 0
# 2 3841 413 7.1646 7.1646 413 0
# 3 3770 484 6.3533 6.3533 484 0
# 4 3807 447 6.6756 6.6756 447 0
# 5 3844 410 6.0439 6.0439 410 0
# 6 3808 446 6.4978 6.4978 446 0
# 7 3832 422 6.0308 6.0308 422 0
# 8 3855 399 7.3283 7.3283 399 0
# 9 3871 383 6.5144 6.5144 383 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3801 453 6.0706 6.0706 453 0
# 1 3869 385 6.4442 6.4442 385 0
# 2 3821 433 6.2702 6.2702 433 0
# 3 3827 427 7.0515 7.0515 427 0
# 4 3851 403 5.8486 5.8486 403 0
# 5 3849 405 6.3086 6.3086 405 0
# 6 3828 426 6.6667 6.6667 426 0
# 7 3834 420 6.4786 6.4786 420 0
# 8 3803 451 6.9933 6.9933 451 0
# 9 3803 451 6.4169 6.4169 451 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3831 423 6.3617 6.3617 423 0
# 1 3881 373 6.5442 6.5442 373 0
# 2 3820 434 5.6083 5.6083 434 0
# 3 3798 456 5.6316 5.6316 456 0
# 4 3819 435 6.7356 6.7356 435 0
# 5 3847 407 6.8182 6.8182 407 0
# 6 3805 449 7.2695 7.2695 449 0
# 7 3842 412 6.5316 6.5316 412 0
# 8 3827 427 6.6838 6.6838 427 0
# 9 3816 438 6.4612 6.4612 438 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3819 435 6.5747 6.5747 435 0
# 1 3848 406 6.2759 6.2759 406 0
# 2 3855 399 6.3684 6.3684 399 0
# 3 3841 413 6.8765 6.8765 413 0
# 4 3817 437 5.6178 5.6178 437 0
# 5 3824 430 6.2047 6.2047 430 0
# 6 3827 427 6.5176 6.5176 427 0
# 7 3814 440 6.6659 6.6659 440 0
# 8 3787 467 6.8779 6.8779 467 0
# 9 3854 400 6.595 6.595 400 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3819 435 5.8736 5.8736 435 0
# 1 3858 396 6.2525 6.2525 396 0
# 2 3746 508 6.0866 6.0866 508 0
# 3 3817 437 7.2883 7.2883 437 0
# 4 3854 400 6.62 6.62 400 0
# 5 3865 389 6.2853 6.2853 389 0
# 6 3853 401 7.1845 7.1845 401 0
# 7 3820 434 6.447 6.447 434 0
# 8 3846 408 6.3995 6.3995 408 0
# 9 3808 446 6.2489 6.2489 446 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3809 445 6.0966 6.0966 445 0
# 1 3863 391 7.0972 7.0972 391 0
# 2 3831 423 6.3168 6.3168 423 0
# 3 3846 408 5.5711 5.5711 408 0
# 4 3822 432 6.6181 6.6181 432 0
# 5 3860 394 6.5254 6.5254 394 0
# 6 3819 435 6.0897 6.0897 435 0
# 7 3837 417 6.2326 6.2326 417 0
# 8 3834 420 7.0762 7.0762 420 0
# 9 3765 489 6.9427 6.9427 489 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3775 479 5.785 5.785 479 0
# 1 3834 420 7.1262 7.1262 420 0
# 2 3818 436 6.4289 6.4289 436 0
# 3 3835 419 6.7375 6.7375 419 0
# 4 3869 385 6.1221 6.1221 385 0
# 5 3819 435 6.4207 6.4207 435 0
# 6 3827 427 7.4075 7.4075 427 0
# 7 3812 442 6.629 6.629 442 0
# 8 3867 387 5.8114 5.8114 387 0
# 9 3830 424 6.1226 6.1226 424 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3839 415 5.8337 5.8337 415 0
# 1 3838 416 6.9663 6.9663 416 0
# 2 3864 390 7.1974 7.1974 390 0
# 3 3824 430 5.9814 5.9814 430 0
# 4 3808 446 6.8296 6.8296 446 0
# 5 3776 478 6.272 6.272 478 0
# 6 3833 421 7.0095 7.0095 421 0
# 7 3836 418 6.0885 6.0885 418 0
# 8 3823 431 6.1253 6.1253 431 0
# 9 3845 409 6.357 6.357 409 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3842 412 6.8908 6.8908 412 0
# 1 3854 400 6.3825 6.3825 400 0
# 2 3788 466 5.8627 5.8627 466 0
# 3 3822 432 5.7986 5.7986 432 0
# 4 3828 426 6.9038 6.9038 426 0
# 5 3857 397 6.2972 6.2972 397 0
# 6 3804 450 6.6933 6.6933 450 0
# 7 3830 424 6.5991 6.5991 424 0
# 8 3879 375 6.768 6.768 375 0
# 9 3782 472 6.4831 6.4831 472 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3852 402 6.5174 6.5174 402 0
# 1 3830 424 7.0802 7.0802 424 0
# 2 3839 415 6.7253 6.7253 415 0
# 3 3798 456 6.7588 6.7588 456 0
# 4 3845 409 6.8142 6.8142 409 0
# 5 3831 423 5.9433 5.9433 423 0
# 6 3846 408 6.0784 6.0784 408 0
# 7 3811 443 6.6479 6.6479 443 0
# 8 3848 406 5.67 5.67 406 0
# 9 3786 468 6.3141 6.3141 468 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3755 499 6.02 6.02 499 0
# 1 3841 413 6.5254 6.5254 413 0
# 2 3852 402 5.7736 5.7736 402 0
# 3 3834 420 7.7857 7.7857 420 0
# 4 3832 422 6.6848 6.6848 422 0
# 5 3817 437 5.8627 5.8627 437 0
# 6 3852 402 6.7886 6.7886 402 0
# 7 3856 398 6.8216 6.8216 398 0
# 8 3811 443 6.307 6.307 443 0
# 9 3836 418 6.1411 6.1411 418 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3838 416 5.7837 5.7837 416 0
# 1 3829 425 6.1835 6.1835 425 0
# 2 3835 419 6.7064 6.7064 419 0
# 3 3816 438 7.6781 7.6781 438 0
# 4 3822 432 6.3981 6.3981 432 0
# 5 3858 396 6.2828 6.2828 396 0
# 6 3788 466 6.3305 6.3305 466 0
# 7 3854 400 5.99 5.99 400 0
# 8 3858 396 6.5455 6.5455 396 0
# 9 3788 466 6.6116 6.6116 466 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3836 418 6.1148 6.1148 418 0
# 1 3842 412 6.3301 6.3301 412 0
# 2 3834 420 6.6095 6.6095 420 0
# 3 3818 436 6.2798 6.2798 436 0
# 4 3810 444 6.5158 6.5158 444 0
# 5 3863 391 6.1535 6.1535 391 0
# 6 3843 411 6.9927 6.9927 411 0
# 7 3791 463 6.6156 6.6156 463 0
# 8 3841 413 6.5109 6.5109 413 0
# 9 3808 446 6.4462 6.4462 446 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3819 435 6.1793 6.1793 435 0
# 1 3848 406 6.4532 6.4532 406 0
# 2 3812 442 6.5362 6.5362 442 0
# 3 3838 416 6.5962 6.5962 416 0
# 4 3835 419 6.2506 6.2506 419 0
# 5 3814 440 6.3091 6.3091 440 0
# 6 3839 415 6.1928 6.1928 415 0
# 7 3800 454 6.2313 6.2313 454 0
# 8 3843 411 6.927 6.927 411 0
# 9 3838 416 6.9615 6.9615 416 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3851 403 6.6005 6.6005 403 0
# 1 3814 440 5.9705 5.9705 440 0
# 2 3806 448 6.5134 6.5134 448 0
# 3 3848 406 6.4655 6.4655 406 0
# 4 3835 419 6.0453 6.0453 419 0
# 5 3836 418 5.8373 5.8373 418 0
# 6 3842 412 7.3908 7.3908 412 0
# 7 3834 420 6.4524 6.4524 420 0
# 8 3829 425 6.3506 6.3506 425 0
# 9 3791 463 6.9568 6.9568 463 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3761 493 6.5172 6.5172 493 0
# 1 3847 407 6.312 6.312 407 0
# 2 3808 446 7.1233 7.1233 446 0
# 3 3836 418 6.3804 6.3804 418 0
# 4 3848 406 6.1429 6.1429 406 0
# 5 3813 441 6.0703 6.0703 441 0
# 6 3830 424 6.2854 6.2854 424 0
# 7 3862 392 6.2423 6.2423 392 0
# 8 3850 404 6.552 6.552 404 0
# 9 3831 423 6.9078 6.9078 423 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3870 384 6.151 6.151 384 0
# 1 3849 405 6.7704 6.7704 405 0
# 2 3835 419 6.2601 6.2601 419 0
# 3 3839 415 5.494 5.494 415 0
# 4 3806 448 6.2188 6.2188 448 0
# 5 3810 444 6.3018 6.3018 444 0
# 6 3785 469 7.6567 7.6567 469 0
# 7 3834 420 6.6762 6.6762 420 0
# 8 3828 426 7.1056 7.1056 426 0
# 9 3830 424 5.8137 5.8137 424 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3812 442 5.8665 5.8665 442 0
# 1 3811 443 6.3431 6.3431 443 0
# 2 3860 394 6.2462 6.2462 394 0
# 3 3789 465 6.7656 6.7656 465 0
# 4 3842 412 6.8956 6.8956 412 0
# 5 3817 437 6.2243 6.2243 437 0
# 6 3840 414 6.5242 6.5242 414 0
# 7 3863 391 5.9258 5.9258 391 0
# 8 3842 412 6.4029 6.4029 412 0
# 9 3810 444 7.3221 7.3221 444 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3835 419 7.21 7.21 419 0
# 1 3837 417 6.7218 6.7218 417 0
# 2 3823 431 6.3202 6.3202 431 0
# 3 3849 405 6.316 6.316 405 0
# 4 3857 397 6.6927 6.6927 397 0
# 5 3807 447 5.689 5.689 447 0
# 6 3815 439 6.8428 6.8428 439 0
# 7 3804 450 6.3533 6.3533 450 0
# 8 3819 435 6.1885 6.1885 435 0
# 9 3840 414 6.3213 6.3213 414 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3801 453 5.8675 5.8675 453 0
# 1 3866 388 7.3093 7.3093 388 0
# 2 3845 409 6.4425 6.4425 409 0
# 3 3825 429 6.2704 6.2704 429 0
# 4 3802 452 5.9646 5.9646 452 0
# 5 3818 436 5.8693 5.8693 436 0
# 6 3815 439 7.5216 7.5216 439 0
# 7 3850 404 6.495 6.495 404 0
# 8 3821 433 6.3857 6.3857 433 0
# 9 3843 411 6.601 6.601 411 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3785 469 5.7292 5.7292 469 0
# 1 3838 416 6.6707 6.6707 416 0
# 2 3790 464 6.4828 6.4828 464 0
# 3 3831 423 6.4492 6.4492 423 0
# 4 3849 405 5.7062 5.7062 405 0
# 5 3831 423 6.8369 6.8369 423 0
# 6 3814 440 6.3682 6.3682 440 0
# 7 3795 459 6.915 6.915 459 0
# 8 3892 362 6.4365 6.4365 362 0
# 9 3861 393 7.0509 7.0509 393 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3813 441 6.4059 6.4059 441 0
# 1 3850 404 6.7129 6.7129 404 0
# 2 3831 423 5.8913 5.8913 423 0
# 3 3797 457 6.1969 6.1969 457 0
# 4 3853 401 6.8204 6.8204 401 0
# 5 3806 448 6.0737 6.0737 448 0
# 6 3816 438 7.0068 7.0068 438 0
# 7 3825 429 6.6177 6.6177 429 0
# 8 3847 407 6.774 6.774 407 0
# 9 3848 406 6.1478 6.1478 406 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3802 452 6.7412 6.7412 452 0
# 1 3841 413 6.7409 6.7409 413 0
# 2 3823 431 6.4037 6.4037 431 0
# 3 3810 444 6.8581 6.8581 444 0
# 4 3790 464 5.9224 5.9224 464 0
# 5 3873 381 6.769 6.769 381 0
# 6 3829 425 6.6047 6.6047 425 0
# 7 3847 407 5.8894 5.8894 407 0
# 8 3823 431 6.5058 6.5058 431 0
# 9 3848 406 6.1749 6.1749 406 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3858 396 5.6616 5.6616 396 0
# 1 3787 467 5.6938 5.6938 467 0
# 2 3848 406 6.6404 6.6404 406 0
# 3 3809 445 7.3528 7.3528 445 0
# 4 3857 397 7.3829 7.3829 397 0
# 5 3853 401 6.5262 6.5262 401 0
# 6 3838 416 6.0361 6.0361 416 0
# 7 3839 415 6.853 6.853 415 0
# 8 3794 460 6.2674 6.2674 460 0
# 9 3803 451 6.2594 6.2594 451 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3805 449 6.2806 6.2806 449 0
# 1 3850 404 6.3391 6.3391 404 0
# 2 3814 440 6.3727 6.3727 440 0
# 3 3803 451 6.5721 6.5721 451 0
# 4 3799 455 6.433 6.433 455 0
# 5 3856 398 6.1281 6.1281 398 0
# 6 3858 396 7.0606 7.0606 396 0
# 7 3832 422 6.5379 6.5379 422 0
# 8 3837 417 6.235 6.235 417 0
# 9 3832 422 6.654 6.654 422 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3812 442 7.371 7.371 442 0
# 1 3791 463 6.7624 6.7624 463 0
# 2 3793 461 7.5944 7.5944 461 0
# 3 3837 417 5.6307 5.6307 417 0
# 4 3856 398 6.0955 6.0955 398 0
# 5 3853 401 5.8653 5.8653 401 0
# 6 3847 407 6.1253 6.1253 407 0
# 7 3818 436 6.7683 6.7683 436 0
# 8 3861 393 6.2723 6.2723 393 0
# 9 3818 436 5.8555 5.8555 436 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3831 423 6.3688 6.3688 423 0
# 1 3831 423 7.3097 7.3097 423 0
# 2 3829 425 5.8612 5.8612 425 0
# 3 3792 462 6.0346 6.0346 462 0
# 4 3855 399 5.8446 5.8446 399 0
# 5 3806 448 6.2054 6.2054 448 0
# 6 3804 450 7.0089 7.0089 450 0
# 7 3850 404 6.8837 6.8837 404 0
# 8 3824 430 6.6698 6.6698 430 0
# 9 3864 390 6.4051 6.4051 390 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3825 429 6.9184 6.9184 429 0
# 1 3800 454 5.63 5.63 454 0
# 2 3854 400 6.965 6.965 400 0
# 3 3823 431 6.877 6.877 431 0
# 4 3846 408 6.5417 6.5417 408 0
# 5 3814 440 6.0523 6.0523 440 0
# 6 3846 408 6.3676 6.3676 408 0
# 7 3824 430 6.1093 6.1093 430 0
# 8 3840 414 6.2126 6.2126 414 0
# 9 3814 440 6.9886 6.9886 440 0
# ***End get_folds method***

# %%
len(cv_folds)
# Out:
# 500

# %%
# Initializing BootStrapFeatImp object
btstrp_featimp = BootstrapFeatImp(num_df, encoded_cat_df, y, cv_folds)

# %%
# Numerical Features Importance
numfeat_df, numfeat_noise_df = btstrp_featimp.run_numfeat_wrapper()
# Out:
# 100%|██████████| 500/500 [1:30:30<00:00, 10.86s/it]

# %%
# Saving the details..
numfeat_df.to_csv("inst_medicaid_numfeat_df.csv", index=False)
numfeat_noise_df.to_csv("inst_medicaid_numfeat_noise_df.csv", index=False)

# %%
numfeat_noise_df
# Out:
#                          feature_name ge_noise
# 12                  count_of_holidays      500
# 2         days_taken_for_claim_filing      472
# 0           total_claim_charge_amount      390
# 5                  count_of_lineitems      306
# 1                  units_sum_quantity      301
# 3                         patient_age      285
# 8             count_of_total_dx_codes      227
# 7                                 LOS      201
# 9      count_of_OccurrenceInformation      190
# 11  count_of_ExternalCauseOfInjury_HI      190
# 4                 units_mean_quantity      178
# 6               units_median_quantity      170
# 10                 days_mean_quantity      158
# 13                              noise        0

# %%
# Categorical Features Importance
catfeat_df, catfeat_noise_df = btstrp_featimp.run_catfeat_wrapper()
# Out:
# 100%|██████████| 500/500 [24:02<00:00,  2.88s/it]

# %%
# Saving the details..
catfeat_df.to_csv("inst_medicaid_catfeat_df_v2.csv", index=False)
catfeat_noise_df.to_csv("inst_medicaid_catfeat_noise_df_v2.csv", index=False)

# %%
catfeat_noise_df
# Out:
#                                          feature_name ge_noise
# 26                             claim_creation_weekday      500
# 13                       RevCode_Radiology_Diagnostic      419
# 9                      RevCode_Other_Imaging_Services      345
# 35                                         payer_name      316
# 31                    claim_has_referring_provider_id      281
# 36                                 payer_resp_seq_num      276
# 6                                  RevCode_Laboratory      271
# 39                              subscriber_pat_gender      268
# 37                                    subscriber_city      263
# 16    ccsr_category_1_code_ExternalCauseOfInjury_HI_1      261
# 4                                   HCPCSCode_Surgery      260
# 14                              admission_source_code      259
# 15                                admission_type_code      258
# 38                                  subscriber_gender      258
# 5                              RevCode_Emergency_Room      257
# 30               claim_has_payer_claim_control_number      250
# 32                                   other_hcpcscodes      244
# 11               RevCode_Pharmacy_-_Extension_of_025X      243
# 33                                     other_ndccodes      242
# 27                               claim_freq_type_code      241
# 8                     RevCode_Operating_Room_Services      238
# 3       HCPCSCode_Pathology_and_Laboratory_Procedures      232
# 12                           RevCode_Physical_Therapy      226
# 21          ccsr_category_1_code_PrincipalDiagnosis_1      225
# 34                                     other_revcodes      207
# 10                                   RevCode_Pharmacy      198
# 7       RevCode_Medical/Surgical_Supplies_and_Devices      195
# 2          HCPCSCode_Medicine_Services_and_Procedures      191
# 25                             claim_creation_quarter      188
# 29                   claim_has_operating_physician_id      184
# 24                               claim_creation_month      182
# 17  ccsr_category_1_code_OtherDiagnosisInformation...      182
# 22                          claim_creation_dayofmonth      175
# 19  ccsr_category_1_code_OtherDiagnosisInformation...      173
# 18  ccsr_category_1_code_OtherDiagnosisInformation...      167
# 0                 Description_OccurrenceInformation_1      138
# 1                 Description_OccurrenceInformation_2      134
# 28                           claim_has_admission_dthr       99
# 20     ccsr_category_1_code_Patient’SReasonForVisit_1       72
# 23                                claim_creation_hour       59
# 40                                              noise        0
