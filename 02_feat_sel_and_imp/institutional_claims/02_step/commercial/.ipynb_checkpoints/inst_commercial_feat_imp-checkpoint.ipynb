# %% [markdown]
# ### Bootstrap Feature Imporatance Computation for Institutional Claims Commercial Model.
# - This notebook captures the steps involved in computing feature importance scores across 500 cross-validation folds.
# - Further this notebook also holds the information on the number of times a feature was ranked higher than noise variable - for both numerical and categorical features data.

# %%
# Importing the required libraries
import os
import sys
import warnings
import numpy as np
import pandas as pd

warnings.filterwarnings("ignore")

# %%
# Adding dependency python files to sys path
sys.path[1:1] = ["/home/ec2-user/SageMaker/GitHub Repos/cipy/cipy/"]
sys.path[2:2] = ["/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/"]
sys.path[3:3] = ["/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/02_feat_sel_and_imp/"]
sys.path[4:4] = ["/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/02_feat_sel_and_imp/institutional_claims/02_step"]

sys.path
# Out:
# ['/home/ec2-user/SageMaker/envs/wqp_env/lib/python3.6',
#  '/home/ec2-user/SageMaker/GitHub Repos/cipy/cipy/',
#  '/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/',
#  '/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/02_feat_sel_and_imp/',
#  '/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/02_feat_sel_and_imp/institutional_claims/02_step',
#  '/home/ec2-user/SageMaker/GitHub Repos/cipy/cipy/',
#  '/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/',
#  '/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/02_feat_sel_and_imp/',
#  '/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/02_feat_sel_and_imp/institutional_claims/02_step',
#  '',
#  '/home/ec2-user/SageMaker/envs/wqp_env/lib/python3.6/site-packages',
#  '/home/ec2-user/SageMaker/envs/wqp_env/lib/python3.6/lib-dynload',
#  '/home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6',
#  '/home/ec2-user/SageMaker/envs/wqp_env/lib/python3.6/site-packages/IPython/extensions',
#  '/home/ec2-user/.ipython']

# %%
# Importing methods from wqp_methods path file, especially get_cvfolds will be leveraged in this notebook.
from wqp_methods import *

# %%
# Importing BootStrapFeatImp class for computing Feature Importance Scores
from bootstrap_feat_imp import BootstrapFeatImp

# %%
# Reading the Institutional claims dataset
ref_col= "claim_filing_ind_code3"

# csv_path for Institutional Claims Data Path
csv_path = "/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/01_data_preprocessing/preprocessed_datasets/"

# Loading the institutional claims dataset into inst_claims
inst_claims = pd.read_csv(csv_path+"ic_preprocessed_dataset_2021-06-06.csv")

# Creating the event_flag - for survival analysis.
inst_claims["event_flag"] = True

# %%
# Load the feature information after preprocessing - 01 Notebook output
filtered_columns_data = pickl("/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/02_feat_sel_and_imp/institutional_claims/02_step/inst_claims_cat_num_filtered_feature_details.pickle")

# Derive Final Model Features for..
claim_filing_indicator_code = "Commercial Insurance Co."
    
# Retrieving claim_filing_indicator_code specific data
cfic_df = inst_claims[inst_claims[ref_col]==claim_filing_indicator_code].reset_index()

# Clipping the response_time values as per claim_filing_indicator_code specific percentiles
cfic_df = clip_right_tail2(cfic_df, 0.99)

# Creating the structured array with event_flag and response_time values.
y = Surv.from_arrays(cfic_df["event_flag"].values, cfic_df["response_time"].values)

# Retrieving categorical features..
cat_cols = filtered_columns_data[claim_filing_indicator_code]["final_cat_cols"]
cat_df = cfic_df[cat_cols]

# Encoding categorical features..
le = LabelEncoder()
encoded_cat_df = cat_df.apply(lambda col: le.fit_transform(col.astype(str)), axis=0, result_type="expand")

# Adding noise variable for categorical data
np.random.seed(0)
encoded_cat_df["noise"] = np.random.poisson(5, size=len(encoded_cat_df))

# Retrieving numerical features..
num_cols = filtered_columns_data[claim_filing_indicator_code]["final_num_cols"]
num_df = cfic_df[num_cols]

# Adding noise variable for numerical data
np.random.seed(0)
num_df["noise"] = np.random.normal(0, 1, len(num_df))

# %%
cv_folds = []

if os.path.isfile("inst_commercial_cv_folds.pickle"):
    cv_folds=pickl("inst_commercial_cv_folds.pickle")

else:
    for i in range(50):
        cv_folds += get_folds(cfic_df)
        
    pickl("inst_commercial_cv_folds.pickle", cv_folds)
# Out:
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 779 83 11.289 11.289 83 0
# 1 774 88 10.08 10.08 88 0
# 2 776 86 8.8372 8.8372 86 0
# 3 752 110 13.191 13.191 110 0
# 4 783 79 12.797 12.797 79 0
# 5 785 77 10.688 10.688 77 0
# 6 777 85 10.071 10.071 85 0
# 7 777 85 11.729 11.729 85 0
# 8 792 70 10.143 10.143 70 0
# 9 763 99 12.505 12.505 99 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 776 86 10.686 10.686 86 0
# 1 777 85 11.341 11.341 85 0
# 2 782 80 12.375 12.375 80 0
# 3 764 98 12.357 12.357 98 0
# 4 773 89 9.5843 9.5843 89 0
# 5 781 81 13.407 13.407 81 0
# 6 771 91 11.264 11.264 91 0
# 7 775 87 10.23 10.23 87 0
# 8 774 88 10.375 10.375 88 0
# 9 785 77 10.636 10.636 77 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 780 82 9.5 9.5 82 0
# 1 766 96 10.26 10.26 96 0
# 2 785 77 11.429 11.429 77 0
# 3 776 86 13.116 13.116 86 0
# 4 780 82 12.366 12.366 82 0
# 5 768 94 13.883 13.883 94 0
# 6 766 96 12.0 12.0 96 0
# 7 786 76 8.7895 8.7895 76 0
# 8 776 86 9.9186 9.9186 86 0
# 9 775 87 10.414 10.414 87 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 781 81 11.802 11.802 81 0
# 1 782 80 10.988 10.988 80 0
# 2 775 87 11.092 11.092 87 0
# 3 765 97 11.68 11.68 97 0
# 4 782 80 11.7 11.7 80 0
# 5 775 87 12.046 12.046 87 0
# 6 775 87 11.575 11.575 87 0
# 7 770 92 10.304 10.304 92 0
# 8 784 78 9.3462 9.3462 78 0
# 9 769 93 11.495 11.495 93 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 764 98 13.112 13.112 98 0
# 1 784 78 11.269 11.269 78 0
# 2 774 88 11.068 11.068 88 0
# 3 786 76 12.421 12.421 76 0
# 4 761 101 12.218 12.218 101 0
# 5 772 90 11.311 11.311 90 0
# 6 784 78 10.013 10.013 78 0
# 7 777 85 10.271 10.271 85 0
# 8 776 86 11.093 11.093 86 0
# 9 780 82 8.878 8.878 82 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 772 90 10.544 10.544 90 0
# 1 781 81 11.099 11.099 81 0
# 2 767 95 11.916 11.916 95 0
# 3 763 99 11.0 11.0 99 0
# 4 788 74 11.27 11.27 74 0
# 5 778 84 10.774 10.774 84 0
# 6 784 78 9.2308 9.2308 78 0
# 7 777 85 11.824 11.824 85 0
# 8 773 89 10.404 10.404 89 0
# 9 775 87 13.92 13.92 87 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 784 78 11.692 11.692 78 0
# 1 787 75 11.027 11.027 75 0
# 2 768 94 11.245 11.245 94 0
# 3 760 102 11.176 11.176 102 0
# 4 776 86 11.081 11.081 86 0
# 5 778 84 10.75 10.75 84 0
# 6 773 89 10.64 10.64 89 0
# 7 784 78 10.936 10.936 78 0
# 8 773 89 10.157 10.157 89 0
# 9 775 87 13.494 13.494 87 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 772 90 11.278 11.278 90 0
# 1 766 96 11.969 11.969 96 0
# 2 783 79 10.861 10.861 79 0
# 3 777 85 12.188 12.188 85 0
# 4 776 86 11.244 11.244 86 0
# 5 776 86 10.407 10.407 86 0
# 6 772 90 11.433 11.433 90 0
# 7 775 87 11.759 11.759 87 0
# 8 786 76 13.026 13.026 76 0
# 9 775 87 8.1379 8.1379 87 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 784 78 9.4744 9.4744 78 0
# 1 773 89 11.135 11.135 89 0
# 2 781 81 10.568 10.568 81 0
# 3 765 97 10.546 10.546 97 0
# 4 785 77 10.701 10.701 77 0
# 5 771 91 12.725 12.725 91 0
# 6 783 79 12.025 12.025 79 0
# 7 767 95 11.432 11.432 95 0
# 8 762 100 11.6 11.6 100 0
# 9 787 75 11.773 11.773 75 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 768 94 12.149 12.149 94 0
# 1 778 84 12.167 12.167 84 0
# 2 756 106 9.934 9.934 106 0
# 3 767 95 12.674 12.674 95 0
# 4 778 84 9.7381 9.7381 84 0
# 5 784 78 10.449 10.449 78 0
# 6 787 75 10.773 10.773 75 0
# 7 775 87 11.425 11.425 87 0
# 8 777 85 11.318 11.318 85 0
# 9 788 74 11.514 11.514 74 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 785 77 13.195 13.195 77 0
# 1 781 81 11.123 11.123 81 0
# 2 759 103 10.252 10.252 103 0
# 3 765 97 12.031 12.031 97 0
# 4 782 80 11.963 11.963 80 0
# 5 771 91 10.736 10.736 91 0
# 6 773 89 10.91 10.91 89 0
# 7 778 84 11.048 11.048 84 0
# 8 789 73 10.781 10.781 73 0
# 9 775 87 10.46 10.46 87 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 774 88 10.67 10.67 88 0
# 1 774 88 12.159 12.159 88 0
# 2 779 83 10.88 10.88 83 0
# 3 771 91 12.165 12.165 91 0
# 4 781 81 10.605 10.605 81 0
# 5 767 95 9.7895 9.7895 95 0
# 6 774 88 11.273 11.273 88 0
# 7 786 76 12.539 12.539 76 0
# 8 783 79 11.278 11.278 79 0
# 9 769 93 11.032 11.032 93 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 790 72 11.25 11.25 72 0
# 1 791 71 10.549 10.549 71 0
# 2 774 88 11.011 11.011 88 0
# 3 762 100 12.29 12.29 100 0
# 4 782 80 12.175 12.175 80 0
# 5 779 83 10.843 10.843 83 0
# 6 763 99 10.222 10.222 99 0
# 7 772 90 11.367 11.367 90 0
# 8 768 94 11.298 11.298 94 0
# 9 777 85 11.082 11.082 85 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 760 102 11.51 11.51 102 0
# 1 782 80 11.6 11.6 80 0
# 2 769 93 11.505 11.505 93 0
# 3 769 93 10.882 10.882 93 0
# 4 786 76 11.5 11.5 76 0
# 5 780 82 12.012 12.012 82 0
# 6 783 79 10.468 10.468 79 0
# 7 771 91 10.659 10.659 91 0
# 8 783 79 11.278 11.278 79 0
# 9 775 87 10.793 10.793 87 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 781 81 10.222 10.222 81 0
# 1 780 82 11.573 11.573 82 0
# 2 757 105 10.19 10.19 105 0
# 3 765 97 12.619 12.619 97 0
# 4 778 84 10.69 10.69 84 0
# 5 776 86 9.8837 9.8837 86 0
# 6 770 92 13.598 13.598 92 0
# 7 777 85 11.718 11.718 85 0
# 8 786 76 11.592 11.592 76 0
# 9 788 74 9.7703 9.7703 74 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 776 86 11.14 11.14 86 0
# 1 773 89 11.213 11.213 89 0
# 2 774 88 12.114 12.114 88 0
# 3 770 92 13.272 13.272 92 0
# 4 785 77 11.416 11.416 77 0
# 5 783 79 10.443 10.443 79 0
# 6 758 104 10.942 10.942 104 0
# 7 779 83 11.807 11.807 83 0
# 8 782 80 8.325 8.325 80 0
# 9 778 84 11.179 11.179 84 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 778 84 10.357 10.357 84 0
# 1 789 73 10.11 10.11 73 0
# 2 776 86 11.093 11.093 86 0
# 3 748 114 11.842 11.842 114 0
# 4 768 94 12.819 12.819 94 0
# 5 767 95 11.053 11.053 95 0
# 6 787 75 12.867 12.867 75 0
# 7 782 80 10.438 10.438 80 0
# 8 781 81 10.667 10.667 81 0
# 9 782 80 10.488 10.488 80 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 782 80 11.787 11.787 80 0
# 1 787 75 10.813 10.813 75 0
# 2 783 79 11.975 11.975 79 0
# 3 763 99 11.505 11.505 99 0
# 4 788 74 10.297 10.297 74 0
# 5 785 77 10.169 10.169 77 0
# 6 773 89 12.955 12.955 89 0
# 7 748 114 11.211 11.211 114 0
# 8 771 91 9.8681 9.8681 91 0
# 9 778 84 11.393 11.393 84 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 780 82 13.707 13.707 82 0
# 1 770 92 11.239 11.239 92 0
# 2 775 87 9.8276 9.8276 87 0
# 3 759 103 10.874 10.874 103 0
# 4 776 86 10.581 10.581 86 0
# 5 772 90 13.122 13.122 90 0
# 6 779 83 10.024 10.024 83 0
# 7 788 74 11.108 11.108 74 0
# 8 777 85 10.682 10.682 85 0
# 9 782 80 11.05 11.05 80 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 781 81 10.679 10.679 81 0
# 1 768 94 10.532 10.532 94 0
# 2 786 76 11.829 11.829 76 0
# 3 755 107 12.112 12.112 107 0
# 4 776 86 9.8837 9.8837 86 0
# 5 776 86 11.244 11.244 86 0
# 6 777 85 11.129 11.129 85 0
# 7 787 75 10.227 10.227 75 0
# 8 776 86 11.837 11.837 86 0
# 9 776 86 12.465 12.465 86 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 785 77 11.714 11.714 77 0
# 1 780 82 10.256 10.256 82 0
# 2 776 86 10.07 10.07 86 0
# 3 773 89 12.989 12.989 89 0
# 4 769 93 9.6452 9.6452 93 0
# 5 779 83 12.169 12.169 83 0
# 6 774 88 12.455 12.455 88 0
# 7 759 103 10.883 10.883 103 0
# 8 783 79 9.8481 9.8481 79 0
# 9 780 82 12.232 12.232 82 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 753 109 12.284 12.284 109 0
# 1 776 86 9.593 9.593 86 0
# 2 769 93 10.688 10.688 93 0
# 3 782 80 12.713 12.713 80 0
# 4 782 80 10.9 10.9 80 0
# 5 783 79 10.392 10.392 79 0
# 6 770 92 12.967 12.967 92 0
# 7 786 76 10.842 10.842 76 0
# 8 777 85 10.224 10.224 85 0
# 9 780 82 11.171 11.171 82 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 775 87 11.471 11.471 87 0
# 1 780 82 11.427 11.427 82 0
# 2 779 83 10.229 10.229 83 0
# 3 759 103 13.573 13.573 103 0
# 4 789 73 10.726 10.726 73 0
# 5 777 85 10.082 10.082 85 0
# 6 776 86 11.291 11.291 86 0
# 7 789 73 11.384 11.384 73 0
# 8 770 92 12.12 12.12 92 0
# 9 764 98 9.5 9.5 98 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 755 107 11.15 11.15 107 0
# 1 785 77 10.662 10.662 77 0
# 2 780 82 10.354 10.354 82 0
# 3 767 95 11.632 11.632 95 0
# 4 774 88 10.909 10.909 88 0
# 5 773 89 11.809 11.809 89 0
# 6 777 85 10.259 10.259 85 0
# 7 777 85 12.835 12.835 85 0
# 8 780 82 10.268 10.268 82 0
# 9 790 72 12.306 12.306 72 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 783 79 11.57 11.57 79 0
# 1 781 81 10.654 10.654 81 0
# 2 772 90 11.611 11.611 90 0
# 3 769 93 11.677 11.677 93 0
# 4 785 77 11.195 11.195 77 0
# 5 780 82 11.232 11.232 82 0
# 6 774 88 11.67 11.67 88 0
# 7 778 84 10.095 10.095 84 0
# 8 766 96 10.24 10.24 96 0
# 9 770 92 12.185 12.185 92 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 780 82 10.122 10.122 82 0
# 1 779 83 11.494 11.494 83 0
# 2 771 91 12.264 12.264 91 0
# 3 769 93 12.366 12.366 93 0
# 4 778 84 11.417 11.417 84 0
# 5 772 90 10.411 10.411 90 0
# 6 776 86 9.1047 9.1047 86 0
# 7 771 91 11.868 11.868 91 0
# 8 775 87 11.575 11.575 87 0
# 9 787 75 11.387 11.387 75 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 763 99 14.313 14.313 99 0
# 1 772 90 11.578 11.578 90 0
# 2 785 77 11.597 11.597 77 0
# 3 784 78 10.91 10.91 78 0
# 4 774 88 10.955 10.955 88 0
# 5 783 79 10.19 10.19 79 0
# 6 773 89 11.135 11.135 89 0
# 7 782 80 11.425 11.425 80 0
# 8 784 78 8.5385 8.5385 78 0
# 9 758 104 10.837 10.837 104 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 773 89 9.764 9.764 89 0
# 1 775 87 11.391 11.391 87 0
# 2 785 77 9.7922 9.7922 77 0
# 3 765 97 12.588 12.588 97 0
# 4 780 82 12.061 12.061 82 0
# 5 784 78 10.577 10.577 78 0
# 6 778 84 11.905 11.905 84 0
# 7 785 77 12.532 12.532 77 0
# 8 771 91 11.286 11.286 91 0
# 9 762 100 10.29 10.29 100 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 770 92 11.924 11.924 92 0
# 1 790 72 9.375 9.375 72 0
# 2 779 83 8.747 8.747 83 0
# 3 759 103 11.641 11.641 103 0
# 4 773 89 13.236 13.236 89 0
# 5 790 72 12.778 12.778 72 0
# 6 783 79 11.291 11.291 79 0
# 7 775 87 10.31 10.31 87 0
# 8 761 101 9.9505 9.9505 101 0
# 9 778 84 12.869 12.869 84 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 743 119 11.697 11.697 119 0
# 1 775 87 11.103 11.103 87 0
# 2 786 76 12.75 12.75 76 0
# 3 779 83 11.253 11.253 83 0
# 4 781 81 10.568 10.568 81 0
# 5 774 88 11.125 11.125 88 0
# 6 766 96 11.156 11.156 96 0
# 7 793 69 12.493 12.493 69 0
# 8 778 84 9.7381 9.7381 84 0
# 9 783 79 10.418 10.418 79 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 778 84 11.893 11.893 84 0
# 1 783 79 10.228 10.228 79 0
# 2 768 94 10.021 10.021 94 0
# 3 766 96 11.51 11.51 96 0
# 4 777 85 11.682 11.682 85 0
# 5 779 83 11.12 11.12 83 0
# 6 786 76 12.013 12.013 76 0
# 7 777 85 10.765 10.765 85 0
# 8 775 87 10.264 10.264 87 0
# 9 769 93 12.677 12.677 93 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 764 98 10.633 10.633 98 0
# 1 777 85 11.565 11.565 85 0
# 2 781 81 10.951 10.951 81 0
# 3 764 98 11.714 11.714 98 0
# 4 790 72 10.875 10.875 72 0
# 5 762 100 11.84 11.84 100 0
# 6 773 89 11.506 11.506 89 0
# 7 793 69 11.913 11.913 69 0
# 8 776 86 10.837 10.837 86 0
# 9 778 84 10.298 10.298 84 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 761 101 11.475 11.475 101 0
# 1 781 81 10.469 10.469 81 0
# 2 780 82 11.5 11.5 82 0
# 3 772 90 11.044 11.044 90 0
# 4 790 72 12.458 12.458 72 0
# 5 775 87 11.402 11.402 87 0
# 6 779 83 11.036 11.036 83 0
# 7 766 96 11.354 11.354 96 0
# 8 779 83 10.651 10.651 83 0
# 9 775 87 10.885 10.885 87 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 746 116 12.164 12.164 116 0
# 1 775 87 11.161 11.161 87 0
# 2 781 81 10.42 10.42 81 0
# 3 790 72 10.264 10.264 72 0
# 4 776 86 12.128 12.128 86 0
# 5 782 80 10.637 10.637 80 0
# 6 785 77 13.442 13.442 77 0
# 7 777 85 10.647 10.647 85 0
# 8 774 88 10.591 10.591 88 0
# 9 772 90 10.433 10.433 90 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 780 82 11.549 11.549 82 0
# 1 769 93 9.8817 9.8817 93 0
# 2 775 87 12.529 12.529 87 0
# 3 762 100 12.07 12.07 100 0
# 4 783 79 11.684 11.684 79 0
# 5 784 78 10.141 10.141 78 0
# 6 785 77 9.4935 9.4935 77 0
# 7 758 104 10.538 10.538 104 0
# 8 782 80 12.05 12.05 80 0
# 9 780 82 12.22 12.22 82 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 779 83 12.193 12.193 83 0
# 1 782 80 12.125 12.125 80 0
# 2 774 88 9.5909 9.5909 88 0
# 3 772 90 10.822 10.822 90 0
# 4 771 91 10.813 10.813 91 0
# 5 774 88 11.477 11.477 88 0
# 6 779 83 11.241 11.241 83 0
# 7 771 91 11.604 11.604 91 0
# 8 784 78 10.987 10.987 78 0
# 9 772 90 11.444 11.444 90 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 780 82 11.146 11.146 82 0
# 1 787 75 10.893 10.893 75 0
# 2 767 95 11.358 11.358 95 0
# 3 772 90 11.3 11.3 90 0
# 4 784 78 10.449 10.449 78 0
# 5 782 80 9.475 9.475 80 0
# 6 776 86 11.593 11.593 86 0
# 7 774 88 13.875 13.875 88 0
# 8 776 86 10.942 10.942 86 0
# 9 760 102 10.892 10.892 102 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 783 79 9.6835 9.6835 79 0
# 1 782 80 10.775 10.775 80 0
# 2 763 99 10.909 10.909 99 0
# 3 769 93 12.237 12.237 93 0
# 4 778 84 9.4881 9.4881 84 0
# 5 783 79 12.835 12.835 79 0
# 6 771 91 10.901 10.901 91 0
# 7 775 87 12.368 12.368 87 0
# 8 778 84 11.44 11.44 84 0
# 9 776 86 11.453 11.453 86 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 763 99 12.313 12.313 99 0
# 1 781 81 9.4815 9.4815 81 0
# 2 773 89 11.573 11.573 89 0
# 3 762 100 11.41 11.41 100 0
# 4 779 83 12.205 12.205 83 0
# 5 784 78 9.8077 9.8077 78 0
# 6 767 95 12.758 12.758 95 0
# 7 788 74 10.784 10.784 74 0
# 8 778 84 10.571 10.571 84 0
# 9 783 79 10.582 10.582 79 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 775 87 10.552 10.552 87 0
# 1 766 96 9.8958 9.8958 96 0
# 2 778 84 11.464 11.464 84 0
# 3 764 98 11.939 11.939 98 0
# 4 774 88 11.784 11.784 88 0
# 5 782 80 11.475 11.475 80 0
# 6 787 75 11.067 11.067 75 0
# 7 766 96 12.344 12.344 96 0
# 8 786 76 10.039 10.039 76 0
# 9 780 82 11.415 11.415 82 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 770 92 11.848 11.848 92 0
# 1 782 80 10.925 10.925 80 0
# 2 780 82 12.598 12.598 82 0
# 3 766 96 12.052 12.052 96 0
# 4 776 86 10.756 10.756 86 0
# 5 794 68 10.735 10.735 68 0
# 6 784 78 11.026 11.026 78 0
# 7 765 97 10.464 10.464 97 0
# 8 785 77 11.338 11.338 77 0
# 9 756 106 10.5 10.5 106 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 771 91 11.78 11.78 91 0
# 1 773 89 11.966 11.966 89 0
# 2 787 75 10.787 10.787 75 0
# 3 766 96 12.344 12.344 96 0
# 4 786 76 11.868 11.868 76 0
# 5 769 93 12.301 12.301 93 0
# 6 778 84 9.2143 9.2143 84 0
# 7 779 83 10.639 10.639 83 0
# 8 778 84 10.56 10.56 84 0
# 9 771 91 10.429 10.429 91 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 787 75 12.787 12.787 75 0
# 1 780 82 9.3902 9.3902 82 0
# 2 773 89 11.236 11.236 89 0
# 3 770 92 11.141 11.141 92 0
# 4 784 78 10.513 10.513 78 0
# 5 771 91 11.11 11.11 91 0
# 6 782 80 12.6 12.6 80 0
# 7 769 93 11.097 11.097 93 0
# 8 772 90 11.0 11.0 90 0
# 9 770 92 11.467 11.467 92 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 768 94 10.202 10.202 94 0
# 1 782 80 10.488 10.488 80 0
# 2 787 75 10.187 10.187 75 0
# 3 765 97 11.412 11.412 97 0
# 4 774 88 11.648 11.648 88 0
# 5 788 74 9.4189 9.4189 74 0
# 6 772 90 11.2 11.2 90 0
# 7 767 95 13.684 13.684 95 0
# 8 783 79 10.671 10.671 79 0
# 9 772 90 12.533 12.533 90 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 786 76 9.0921 9.0921 76 0
# 1 781 81 12.63 12.63 81 0
# 2 782 80 11.6 11.6 80 0
# 3 762 100 11.89 11.89 100 0
# 4 769 93 10.204 10.204 93 0
# 5 776 86 11.093 11.093 86 0
# 6 774 88 12.511 12.511 88 0
# 7 774 88 11.568 11.568 88 0
# 8 780 82 9.8293 9.8293 82 0
# 9 774 88 11.489 11.489 88 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 774 88 10.114 10.114 88 0
# 1 787 75 12.653 12.653 75 0
# 2 786 76 10.934 10.934 76 0
# 3 768 94 11.032 11.032 94 0
# 4 774 88 12.511 12.511 88 0
# 5 769 93 10.914 10.914 93 0
# 6 767 95 12.621 12.621 95 0
# 7 769 93 10.183 10.183 93 0
# 8 789 73 10.219 10.219 73 0
# 9 775 87 10.977 10.977 87 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 766 96 10.115 10.115 96 0
# 1 770 92 9.6196 9.6196 92 0
# 2 789 73 13.712 13.712 73 0
# 3 773 89 12.258 12.258 89 0
# 4 785 77 11.649 11.649 77 0
# 5 765 97 11.515 11.515 97 0
# 6 784 78 11.038 11.038 78 0
# 7 763 99 10.869 10.869 99 0
# 8 783 79 10.405 10.405 79 0
# 9 780 82 11.573 11.573 82 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 779 83 10.386 10.386 83 0
# 1 786 76 9.9079 9.9079 76 0
# 2 772 90 11.356 11.356 90 0
# 3 774 88 12.455 12.455 88 0
# 4 765 97 9.7423 9.7423 97 0
# 5 766 96 12.25 12.25 96 0
# 6 785 77 11.779 11.779 77 0
# 7 778 84 11.476 11.476 84 0
# 8 782 80 9.7875 9.7875 80 0
# 9 771 91 12.769 12.769 91 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 770 92 11.826 11.826 92 0
# 1 770 92 11.076 11.076 92 0
# 2 782 80 10.562 10.562 80 0
# 3 767 95 11.905 11.905 95 0
# 4 776 86 11.5 11.5 86 0
# 5 775 87 12.138 12.138 87 0
# 6 787 75 10.813 10.813 75 0
# 7 771 91 9.4725 9.4725 91 0
# 8 787 75 10.093 10.093 75 0
# 9 773 89 12.494 12.494 89 0
# ***End get_folds method***
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 769 93 10.763 10.763 93 0
# 1 776 86 11.407 11.407 86 0
# 2 782 80 10.762 10.762 80 0
# 3 772 90 13.244 13.244 90 0
# 4 787 75 11.653 11.653 75 0
# 5 776 86 9.7093 9.7093 86 0
# 6 777 85 12.235 12.235 85 0
# 7 789 73 11.767 11.767 73 0
# 8 765 97 10.485 10.485 97 0
# 9 765 97 10.412 10.412 97 0
# ***End get_folds method***

# %%
len(cv_folds)
# Out:
# 500

# %%
# Initializing BootStrapFeatImp object
btstrp_featimp = BootstrapFeatImp(num_df, encoded_cat_df, y, cv_folds)

# %%
# Numerical Features Importance
numfeat_df, numfeat_noise_df = btstrp_featimp.run_numfeat_wrapper()
# Out:
# 100%|██████████| 500/500 [06:27<00:00,  1.29it/s]

# %%
# Saving the details..
numfeat_df.to_csv("inst_commercial_numfeat_df.csv", index=False)
numfeat_noise_df.to_csv("inst_commercial_numfeat_noise_df.csv", index=False)

# %%
numfeat_noise_df
# Out:
#                          feature_name ge_noise
# 3                         patient_age      414
# 2         days_taken_for_claim_filing      400
# 9                   count_of_holidays      373
# 0           total_claim_charge_amount      367
# 12         count_of_other_subscribers      360
# 6             count_of_total_dx_codes      346
# 1                  units_sum_quantity      344
# 8   count_of_ExternalCauseOfInjury_HI      333
# 7               units_median_quantity      320
# 4                                 LOS      312
# 10                  days_sum_quantity      308
# 11           count_of_total_pcs_codes      305
# 5                  count_of_lineitems      303
# 13                              noise        0

# %%
# Categorical Features Importance
catfeat_df, catfeat_noise_df = btstrp_featimp.run_catfeat_wrapper()
# Out:
# 100%|██████████| 500/500 [09:57<00:00,  1.19s/it]

# %%
catfeat_df.to_csv("inst_commercial_catfeat_df.csv", index=False)
catfeat_noise_df.to_csv("inst_commercial_catfeat_noise_df.csv", index=False)

# %%
catfeat_noise_df
# Out:
#                                          feature_name ge_noise
# 38                                         payer_city      494
# 39                                         payer_name      493
# 40                                        payer_state      466
# 22                               claim_creation_month      463
# 24                             claim_creation_weekday      432
# 25                              claim_filing_ind_code      425
# 31                                facility_code_value      422
# 23                             claim_creation_quarter      391
# 26                               claim_freq_type_code      379
# 28               claim_has_payer_claim_control_number      375
# 17  ccsr_category_1_code_OtherDiagnosisInformation...      372
# 37                                     patient_gender      365
# 41                                    subscriber_city      359
# 44                               subscriber_pat_reltn      349
# 19          ccsr_category_1_code_PrincipalDiagnosis_1      344
# 18     ccsr_category_1_code_Patient’SReasonForVisit_1      343
# 32                                     ind_reltn_code      334
# 1                      HCPCSCode_Radiology_Procedures      323
# 42                                  subscriber_gender      320
# 13                                admission_type_code      315
# 30        claim_has_subscriber_group_or_policy_number      315
# 5       RevCode_Medical/Surgical_Supplies_and_Devices      314
# 29                    claim_has_referring_provider_id      313
# 35                                     other_ndccodes      308
# 2                                   HCPCSCode_Surgery      306
# 45                                   subscriber_state      306
# 33                                    ind_reltn_code2      306
# 27                           claim_has_admission_dthr      305
# 10                           RevCode_Physical_Therapy      303
# 12                              admission_source_code      302
# 11                       RevCode_Radiology_Diagnostic      300
# 34                                   other_hcpcscodes      299
# 43                              subscriber_pat_gender      298
# 21                                claim_creation_hour      297
# 0       HCPCSCode_Pathology_and_Laboratory_Procedures      295
# 9                RevCode_Pharmacy_-_Extension_of_025X      295
# 7                      RevCode_Other_Imaging_Services      295
# 20                          claim_creation_dayofmonth      289
# 36                                     other_revcodes      287
# 15  ccsr_category_1_code_OtherDiagnosisInformation...      287
# 8                                    RevCode_Pharmacy      287
# 4                                  RevCode_Laboratory      285
# 6                     RevCode_Operating_Room_Services      277
# 3                              RevCode_Emergency_Room      266
# 16  ccsr_category_1_code_OtherDiagnosisInformation...      264
# 14                              attending_provider_id      237
# 46                                              noise        0
