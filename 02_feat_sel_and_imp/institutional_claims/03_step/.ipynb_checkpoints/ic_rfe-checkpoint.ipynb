# %%
import sys
import pickle
import warnings
import pandas as pd
from collections import defaultdict

warnings.filterwarnings("ignore")

# %%
# Adding dependency python files to sys path
sys.path[1:1] = ["/home/ec2-user/SageMaker/GitHub Repos/cipy/cipy/"]
sys.path[2:2] = ["/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/"]
sys.path[3:3] = ["/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/02_feat_sel_and_imp/"]
sys.path[4:4] = ["/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/02_feat_sel_and_imp/institutional_claims/02_step"]

sys.path
# Out:
# ['/home/ec2-user/SageMaker/envs/wqp_env/lib/python3.6',
#  '/home/ec2-user/SageMaker/GitHub Repos/cipy/cipy/',
#  '/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/',
#  '/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/02_feat_sel_and_imp/',
#  '/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/02_feat_sel_and_imp/institutional_claims/02_step',
#  '',
#  '/home/ec2-user/SageMaker/envs/wqp_env/lib/python3.6/site-packages',
#  '/home/ec2-user/SageMaker/envs/wqp_env/lib/python3.6/lib-dynload',
#  '/home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6',
#  '/home/ec2-user/SageMaker/envs/wqp_env/lib/python3.6/site-packages/IPython/extensions',
#  '/home/ec2-user/.ipython']

# %%
from wqp_methods import *

# %%
# Reading the Institutional claims dataset
ref_col= "claim_filing_ind_code3"

# csv_path for Institutional Claims Data Path
csv_path = "/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/01_data_preprocessing/preprocessed_datasets/"

# Loading the institutional claims dataset into inst_claims
inst_claims = pd.read_csv(csv_path+"ic_preprocessed_dataset_2021-06-06.csv")

# Creating the event_flag - for survival analysis.
inst_claims["event_flag"] = True

# %%
claim_filing_ind_codes = inst_claims[ref_col].unique()

# %%
rfe_feat_path = "/home/ec2-user/SageMaker/Users/SP056963/work_queue_prioritization_v2/02_feat_sel_and_imp/institutional_claims/03_step/ic_rfe_output.pickle"

with open(rfe_feat_path, "rb") as input_file:
    rfe_feat_op = pickle.load(input_file)

# %%
cfic_tracker = {}

for claim_filing_ind_code in claim_filing_ind_codes:
    
    print("Claim Filing Indicator Code: {}".format(claim_filing_ind_code))
    
    cfic_df = inst_claims[inst_claims[ref_col]==claim_filing_ind_code].reset_index(drop=True)

    folds = get_folds(cfic_df)
    
    cfic=""
    if "medicaid" in claim_filing_ind_code.lower():
        cfic = "medicaid"
    elif "medicare" in claim_filing_ind_code.lower():
        cfic = "medicare"
    else:
        cfic = "commercial"
        
    num_feats = ic_features_for_rfe[cfic]["num_feat"]
    cat_feats = ic_features_for_rfe[cfic]["cat_feat"]

    encoder_dict = defaultdict(LabelEncoder)
    cat_df = cfic_df[cat_feats].astype("str")
    cat_df = cat_df.apply(lambda x: encoder_dict[x.name].fit_transform(x))

    num_df = cfic_df[num_feats]

    res_df = cfic_df[["response_time", "event_flag"]]

    rsf_df = pd.concat([num_df, cat_df, res_df], axis=1)
    
    features_tracker, c_index_tracker, feat_imp_tracker = recursive_feature_elimination(folds, rsf_df, num_feats+cat_feats)
    
    cfic_tracker[claim_filing_ind_code] = (features_tracker, c_index_tracker, feat_imp_tracker)
# Out:
# Claim Filing Indicator Code: Medicaid
# ***Begin get_folds method***
# fold  #train  #test  timeToResponse   timeToResponseC   Tresponse_tst  Tresponse_shared
# 0 3905 436 11.47 11.47 436 0
# 1 3904 437 14.188 14.188 437 0
# 2 3890 451 9.867 9.867 451 0
# 3 3894 447 7.8881 7.8881 447 0
# 4 3890 451 8.6563 8.6563 451 0
# 5 3933 408 11.681 11.681 408 0
# 6 3910 431 12.188 12.188 431 0
# 7 3935 406 12.643 12.643 406 0
# 8 3923 418 10.124 10.124 418 0
# 9 3885 456 12.684 12.684 456 0
# ***End get_folds method***
# Current Iteration#: 0
#                                                  imp_score_0  imp_score_1  \
# feat_name
# count_of_holidays                                   0.018465     0.033220
# days_taken_for_claim_filing                        -0.009530     0.008344
# total_claim_charge_amount                          -0.003635    -0.005668
# count_of_lineitems                                 -0.006323    -0.005986
# units_sum_quantity                                 -0.017773    -0.023116
# patient_age                                        -0.008578    -0.012426
# claim_creation_weekday                              0.159663     0.124549
# RevCode_Radiology_Diagnostic                        0.002231    -0.002450
# RevCode_Other_Imaging_Services                      0.000876    -0.002111
# payer_name                                         -0.000981    -0.002412
# claim_has_referring_provider_id                    -0.001941     0.001086
# payer_resp_seq_num                                 -0.004038    -0.001380
# RevCode_Laboratory                                 -0.013505    -0.003825
# subscriber_pat_gender                              -0.000952    -0.000727
# subscriber_city                                    -0.000499    -0.004420
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.002973    -0.000351
# HCPCSCode_Surgery                                  -0.005237    -0.000967
# admission_source_code                              -0.005694    -0.006105
# admission_type_code                                -0.006474     0.001214
# subscriber_gender                                  -0.000298    -0.004118
# RevCode_Emergency_Room                             -0.002910     0.003990
# claim_has_payer_claim_control_number               -0.000851    -0.000145
#
#                                                  imp_score_2  imp_score_3  \
# feat_name
# count_of_holidays                                   0.035948     0.018387
# days_taken_for_claim_filing                        -0.029539    -0.022114
# total_claim_charge_amount                          -0.007766    -0.027499
# count_of_lineitems                                 -0.008390    -0.023305
# units_sum_quantity                                 -0.021126    -0.027395
# patient_age                                        -0.011885    -0.032901
# claim_creation_weekday                              0.192083     0.172749
# RevCode_Radiology_Diagnostic                       -0.011873    -0.003651
# RevCode_Other_Imaging_Services                     -0.000059     0.002009
# payer_name                                          0.009100    -0.006694
# claim_has_referring_provider_id                    -0.001569    -0.001175
# payer_resp_seq_num                                 -0.000369    -0.001079
# RevCode_Laboratory                                 -0.007421    -0.023458
# subscriber_pat_gender                               0.000526    -0.001083
# subscriber_city                                     0.002377    -0.010465
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1    -0.000624    -0.000455
# HCPCSCode_Surgery                                  -0.003977    -0.010522
# admission_source_code                              -0.002295    -0.003908
# admission_type_code                                -0.003891    -0.008408
# subscriber_gender                                  -0.004817    -0.006569
# RevCode_Emergency_Room                             -0.002291    -0.005736
# claim_has_payer_claim_control_number               -0.001071    -0.000479
#
#                                                  imp_score_4  imp_score_5  \
# feat_name
# count_of_holidays                                   0.032370     0.022697
# days_taken_for_claim_filing                         0.005490     0.004297
# total_claim_charge_amount                          -0.013442     0.000825
# count_of_lineitems                                 -0.010616    -0.003342
# units_sum_quantity                                 -0.026285    -0.004688
# patient_age                                        -0.006887    -0.007418
# claim_creation_weekday                              0.176620     0.155549
# RevCode_Radiology_Diagnostic                       -0.000912     0.006902
# RevCode_Other_Imaging_Services                      0.000876     0.000593
# payer_name                                          0.002036     0.005354
# claim_has_referring_provider_id                    -0.000703    -0.001534
# payer_resp_seq_num                                 -0.001622     0.003063
# RevCode_Laboratory                                 -0.005936     0.004828
# subscriber_pat_gender                              -0.000193     0.000757
# subscriber_city                                    -0.004870    -0.000328
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.002502    -0.002127
# HCPCSCode_Surgery                                  -0.002684     0.008426
# admission_source_code                              -0.005387    -0.006111
# admission_type_code                                 0.001567    -0.000101
# subscriber_gender                                  -0.005245    -0.001669
# RevCode_Emergency_Room                             -0.001989     0.000994
# claim_has_payer_claim_control_number               -0.000647    -0.003825
#
#                                                  imp_score_6  imp_score_7  \
# feat_name
# count_of_holidays                                   0.033790     0.016719
# days_taken_for_claim_filing                        -0.007625    -0.005762
# total_claim_charge_amount                          -0.002382    -0.009340
# count_of_lineitems                                 -0.015977    -0.022743
# units_sum_quantity                                 -0.010498    -0.019952
# patient_age                                        -0.001642    -0.003282
# claim_creation_weekday                              0.192356     0.199786
# RevCode_Radiology_Diagnostic                       -0.004584    -0.003354
# RevCode_Other_Imaging_Services                      0.002042     0.001757
# payer_name                                          0.002270    -0.000311
# claim_has_referring_provider_id                     0.002036    -0.002607
# payer_resp_seq_num                                 -0.003454    -0.004277
# RevCode_Laboratory                                 -0.011880    -0.010248
# subscriber_pat_gender                              -0.002811    -0.006675
# subscriber_city                                    -0.000362     0.005845
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1    -0.000663    -0.001117
# HCPCSCode_Surgery                                  -0.011152    -0.000981
# admission_source_code                              -0.001874    -0.007330
# admission_type_code                                -0.000471    -0.007389
# subscriber_gender                                   0.000912    -0.004102
# RevCode_Emergency_Room                             -0.001143    -0.005422
# claim_has_payer_claim_control_number               -0.001407     0.002583
#
#                                                  imp_score_8  imp_score_9
# feat_name
# count_of_holidays                                   0.053182     0.028419
# days_taken_for_claim_filing                         0.001590     0.000804
# total_claim_charge_amount                          -0.011788    -0.007302
# count_of_lineitems                                 -0.001517    -0.009827
# units_sum_quantity                                 -0.017659    -0.001234
# patient_age                                        -0.007201     0.001158
# claim_creation_weekday                              0.184285     0.166461
# RevCode_Radiology_Diagnostic                        0.006891     0.006212
# RevCode_Other_Imaging_Services                      0.000770    -0.001101
# payer_name                                          0.001029     0.006559
# claim_has_referring_provider_id                     0.005065    -0.001699
# payer_resp_seq_num                                 -0.004277    -0.000849
# RevCode_Laboratory                                 -0.016739    -0.005424
# subscriber_pat_gender                              -0.007187    -0.001996
# subscriber_city                                     0.009497    -0.001684
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1    -0.002373    -0.001063
# HCPCSCode_Surgery                                  -0.001284    -0.006369
# admission_source_code                               0.001239    -0.000404
# admission_type_code                                -0.005716     0.003333
# subscriber_gender                                  -0.001348    -0.004186
# RevCode_Emergency_Room                             -0.002674    -0.000507
# claim_has_payer_claim_control_number               -0.000506    -0.000457
# Current Iteration#: 1
#                                                  imp_score_0   imp_score_1  \
# feat_name
# count_of_holidays                                   0.023161  4.374964e-02
# days_taken_for_claim_filing                        -0.008746 -3.255095e-03
# total_claim_charge_amount                          -0.008084 -7.989029e-03
# count_of_lineitems                                 -0.014742 -4.791765e-03
# patient_age                                        -0.012364  2.416537e-03
# claim_creation_weekday                              0.185593  1.913959e-01
# RevCode_Radiology_Diagnostic                       -0.001484  1.693641e-03
# RevCode_Other_Imaging_Services                     -0.000268 -3.700743e-17
# payer_name                                         -0.001958 -1.606894e-03
# claim_has_referring_provider_id                    -0.002809  9.005213e-04
# payer_resp_seq_num                                 -0.001426 -4.213448e-04
# RevCode_Laboratory                                 -0.014247 -6.183855e-03
# subscriber_pat_gender                              -0.003748 -1.491230e-03
# subscriber_city                                    -0.006549  2.676779e-03
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.002214  1.887790e-03
# HCPCSCode_Surgery                                  -0.010406 -2.875059e-03
# admission_source_code                              -0.000247 -6.237556e-04
# admission_type_code                                -0.010138  1.074016e-03
# subscriber_gender                                  -0.008654  6.320173e-04
# RevCode_Emergency_Room                             -0.003581  3.222049e-04
# claim_has_payer_claim_control_number               -0.000788 -9.707454e-04
#
#                                                  imp_score_2  imp_score_3  \
# feat_name
# count_of_holidays                                   0.033567     0.024489
# days_taken_for_claim_filing                        -0.019976     0.010514
# total_claim_charge_amount                          -0.019874    -0.014128
# count_of_lineitems                                 -0.009261    -0.013552
# patient_age                                        -0.012889    -0.012075
# claim_creation_weekday                              0.166167     0.168520
# RevCode_Radiology_Diagnostic                        0.000906     0.004069
# RevCode_Other_Imaging_Services                     -0.000890    -0.001759
# payer_name                                          0.001792    -0.005462
# claim_has_referring_provider_id                    -0.000992     0.001699
# payer_resp_seq_num                                 -0.001949     0.008771
# RevCode_Laboratory                                 -0.008409    -0.001409
# subscriber_pat_gender                              -0.004048    -0.003663
# subscriber_city                                    -0.004056     0.002906
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1    -0.002397     0.000173
# HCPCSCode_Surgery                                  -0.008609    -0.007495
# admission_source_code                              -0.002102    -0.002979
# admission_type_code                                -0.002553    -0.005108
# subscriber_gender                                  -0.002852    -0.005430
# RevCode_Emergency_Room                             -0.002083    -0.005200
# claim_has_payer_claim_control_number               -0.000145     0.002375
#
#                                                  imp_score_4  imp_score_5  \
# feat_name
# count_of_holidays                                   0.048532     0.023730
# days_taken_for_claim_filing                        -0.019958    -0.000723
# total_claim_charge_amount                          -0.015210    -0.008537
# count_of_lineitems                                 -0.020444    -0.016273
# patient_age                                        -0.007866    -0.001534
# claim_creation_weekday                              0.141639     0.150808
# RevCode_Radiology_Diagnostic                       -0.001906    -0.000232
# RevCode_Other_Imaging_Services                      0.000699     0.000183
# payer_name                                          0.002254     0.000564
# claim_has_referring_provider_id                    -0.000726    -0.001630
# payer_resp_seq_num                                  0.003090    -0.002281
# RevCode_Laboratory                                 -0.024023    -0.005493
# subscriber_pat_gender                              -0.005308     0.001669
# subscriber_city                                    -0.006180     0.004934
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.001235    -0.001341
# HCPCSCode_Surgery                                  -0.010593    -0.001013
# admission_source_code                               0.003303    -0.004375
# admission_type_code                                -0.004136    -0.011358
# subscriber_gender                                   0.000849    -0.000632
# RevCode_Emergency_Room                             -0.002210    -0.005368
# claim_has_payer_claim_control_number                0.000087    -0.000830
#
#                                                  imp_score_6  imp_score_7  \
# feat_name
# count_of_holidays                                   0.036618     0.025098
# days_taken_for_claim_filing                        -0.013827    -0.001937
# total_claim_charge_amount                          -0.017972    -0.024302
# count_of_lineitems                                 -0.016683    -0.018486
# patient_age                                        -0.001664     0.000408
# claim_creation_weekday                              0.194726     0.186349
# RevCode_Radiology_Diagnostic                        0.000885    -0.003248
# RevCode_Other_Imaging_Services                     -0.000596     0.003107
# payer_name                                         -0.001877    -0.002306
# claim_has_referring_provider_id                     0.000986    -0.000277
# payer_resp_seq_num                                  0.000245     0.000374
# RevCode_Laboratory                                 -0.013905    -0.009102
# subscriber_pat_gender                              -0.002171    -0.006573
# subscriber_city                                    -0.006325    -0.000990
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.003179     0.004447
# HCPCSCode_Surgery                                  -0.010892    -0.012505
# admission_source_code                               0.000568    -0.004039
# admission_type_code                                -0.004973    -0.003952
# subscriber_gender                                  -0.004225    -0.007694
# RevCode_Emergency_Room                             -0.004007    -0.004136
# claim_has_payer_claim_control_number               -0.001868     0.002825
#
#                                                  imp_score_8  imp_score_9
# feat_name
# count_of_holidays                                   0.044104     0.025253
# days_taken_for_claim_filing                        -0.020497     0.004258
# total_claim_charge_amount                          -0.005256    -0.004761
# count_of_lineitems                                 -0.011086    -0.018603
# patient_age                                        -0.005807    -0.005527
# claim_creation_weekday                              0.172230     0.165585
# RevCode_Radiology_Diagnostic                       -0.001271    -0.002144
# RevCode_Other_Imaging_Services                      0.000474    -0.000297
# payer_name                                         -0.006513     0.010665
# claim_has_referring_provider_id                     0.006445    -0.001665
# payer_resp_seq_num                                 -0.001152    -0.000278
# RevCode_Laboratory                                 -0.015787    -0.016965
# subscriber_pat_gender                              -0.003120    -0.005241
# subscriber_city                                     0.008882    -0.001844
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1    -0.000979    -0.000937
# HCPCSCode_Surgery                                  -0.015846    -0.013788
# admission_source_code                              -0.002605    -0.002080
# admission_type_code                                -0.005671    -0.001067
# subscriber_gender                                  -0.000223    -0.001242
# RevCode_Emergency_Room                              0.000906    -0.002659
# claim_has_payer_claim_control_number               -0.001767     0.000156
# Current Iteration#: 2
#                                                  imp_score_0  imp_score_1  \
# feat_name
# count_of_holidays                                   0.028628     0.037975
# days_taken_for_claim_filing                        -0.013077     0.011550
# total_claim_charge_amount                          -0.010708    -0.007175
# patient_age                                        -0.004130    -0.013875
# claim_creation_weekday                              0.141309     0.194548
# RevCode_Radiology_Diagnostic                       -0.003346    -0.000211
# RevCode_Other_Imaging_Services                     -0.006029    -0.003106
# payer_name                                          0.003782     0.001805
# claim_has_referring_provider_id                     0.002373     0.000169
# payer_resp_seq_num                                 -0.003371    -0.001826
# RevCode_Laboratory                                 -0.011459    -0.001991
# subscriber_pat_gender                              -0.001296     0.002512
# subscriber_city                                    -0.004872     0.001681
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.002474     0.001615
# HCPCSCode_Surgery                                  -0.017576    -0.001603
# admission_source_code                              -0.000403    -0.005482
# admission_type_code                                -0.011396     0.008051
# subscriber_gender                                  -0.005924     0.005701
# RevCode_Emergency_Room                             -0.003421    -0.001570
# claim_has_payer_claim_control_number               -0.003342     0.001057
#
#                                                  imp_score_2  imp_score_3  \
# feat_name
# count_of_holidays                                   0.035536     0.033243
# days_taken_for_claim_filing                        -0.010720    -0.005204
# total_claim_charge_amount                          -0.011120    -0.009217
# patient_age                                        -0.009127    -0.010485
# claim_creation_weekday                              0.146165     0.175413
# RevCode_Radiology_Diagnostic                       -0.005272    -0.006670
# RevCode_Other_Imaging_Services                      0.000671    -0.001864
# payer_name                                          0.011006     0.001602
# claim_has_referring_provider_id                    -0.000016     0.000773
# payer_resp_seq_num                                  0.000769     0.004770
# RevCode_Laboratory                                 -0.009555    -0.010852
# subscriber_pat_gender                              -0.004848    -0.006943
# subscriber_city                                    -0.001310    -0.003562
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.005425    -0.002797
# HCPCSCode_Surgery                                  -0.009943    -0.013689
# admission_source_code                              -0.001589    -0.001441
# admission_type_code                                -0.002612    -0.003071
# subscriber_gender                                  -0.005185    -0.005329
# RevCode_Emergency_Room                              0.000471     0.000254
# claim_has_payer_claim_control_number               -0.000282    -0.001670
#
#                                                  imp_score_4  imp_score_5  \
# feat_name
# count_of_holidays                                   0.047798     0.022794
# days_taken_for_claim_filing                        -0.021482    -0.009603
# total_claim_charge_amount                          -0.018881    -0.001331
# patient_age                                        -0.012665    -0.004249
# claim_creation_weekday                              0.179718     0.169544
# RevCode_Radiology_Diagnostic                       -0.004073     0.002542
# RevCode_Other_Imaging_Services                     -0.004629    -0.005267
# payer_name                                         -0.004266     0.006473
# claim_has_referring_provider_id                     0.000221     0.001215
# payer_resp_seq_num                                  0.000442     0.000805
# RevCode_Laboratory                                 -0.009886    -0.001288
# subscriber_pat_gender                              -0.011382    -0.003492
# subscriber_city                                    -0.001105     0.004722
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.000916    -0.003135
# HCPCSCode_Surgery                                   0.003070     0.000593
# admission_source_code                              -0.002143    -0.005580
# admission_type_code                                -0.010249    -0.000410
# subscriber_gender                                  -0.001212     0.002378
# RevCode_Emergency_Room                             -0.000781    -0.000579
# claim_has_payer_claim_control_number               -0.000987    -0.001100
#
#                                                  imp_score_6  imp_score_7  \
# feat_name
# count_of_holidays                                   0.042429     0.030185
# days_taken_for_claim_filing                        -0.017296     0.004388
# total_claim_charge_amount                          -0.014247    -0.015476
# patient_age                                        -0.010192    -0.015034
# claim_creation_weekday                              0.189421     0.195752
# RevCode_Radiology_Diagnostic                       -0.005813    -0.000850
# RevCode_Other_Imaging_Services                     -0.005402    -0.000801
# payer_name                                          0.001939     0.005869
# claim_has_referring_provider_id                    -0.001958    -0.000311
# payer_resp_seq_num                                 -0.002849     0.000733
# RevCode_Laboratory                                 -0.018196    -0.015107
# subscriber_pat_gender                              -0.001416    -0.011185
# subscriber_city                                    -0.004115    -0.002752
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.001775     0.001898
# HCPCSCode_Surgery                                  -0.016229    -0.015481
# admission_source_code                              -0.006379    -0.002685
# admission_type_code                                -0.001668    -0.004719
# subscriber_gender                                  -0.005996    -0.006825
# RevCode_Emergency_Room                             -0.008849    -0.000568
# claim_has_payer_claim_control_number               -0.000956     0.000223
#
#                                                  imp_score_8  imp_score_9
# feat_name
# count_of_holidays                                   0.065657     0.030795
# days_taken_for_claim_filing                         0.002296    -0.009088
# total_claim_charge_amount                           0.004295    -0.007435
# patient_age                                         0.005502    -0.003935
# claim_creation_weekday                              0.145093     0.184180
# RevCode_Radiology_Diagnostic                        0.006076    -0.001185
# RevCode_Other_Imaging_Services                     -0.001002    -0.000998
# payer_name                                          0.002833     0.010284
# claim_has_referring_provider_id                     0.005192     0.003687
# payer_resp_seq_num                                 -0.000629    -0.001813
# RevCode_Laboratory                                 -0.015195    -0.021753
# subscriber_pat_gender                              -0.001048    -0.006346
# subscriber_city                                     0.011792     0.004152
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1    -0.001207     0.000046
# HCPCSCode_Surgery                                  -0.007051    -0.006974
# admission_source_code                              -0.000679    -0.004392
# admission_type_code                                -0.001544    -0.002834
# subscriber_gender                                  -0.004427    -0.008174
# RevCode_Emergency_Room                              0.003011    -0.004495
# claim_has_payer_claim_control_number               -0.001075    -0.000952
# Current Iteration#: 3
#                                                  imp_score_0  imp_score_1  \
# feat_name
# count_of_holidays                                   0.027429     0.036467
# days_taken_for_claim_filing                        -0.017857     0.012289
# total_claim_charge_amount                          -0.020653    -0.005490
# patient_age                                        -0.012616    -0.013099
# claim_creation_weekday                              0.143498     0.160855
# RevCode_Radiology_Diagnostic                       -0.010767    -0.001388
# RevCode_Other_Imaging_Services                     -0.003145     0.001516
# payer_name                                         -0.002889    -0.004094
# claim_has_referring_provider_id                    -0.001824     0.002053
# payer_resp_seq_num                                 -0.001300    -0.000446
# subscriber_pat_gender                              -0.003639    -0.000496
# subscriber_city                                     0.003610    -0.002607
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.003861    -0.000078
# HCPCSCode_Surgery                                  -0.017303     0.001557
# admission_source_code                               0.003771    -0.004007
# admission_type_code                                -0.011081    -0.002181
# subscriber_gender                                  -0.002742     0.000194
# RevCode_Emergency_Room                             -0.002914     0.002557
# claim_has_payer_claim_control_number               -0.000985    -0.002392
#
#                                                  imp_score_2  imp_score_3  \
# feat_name
# count_of_holidays                                   0.039203     0.027218
# days_taken_for_claim_filing                        -0.013528    -0.003011
# total_claim_charge_amount                          -0.002200    -0.026566
# patient_age                                        -0.003299    -0.021417
# claim_creation_weekday                              0.143964     0.177623
# RevCode_Radiology_Diagnostic                       -0.002055    -0.005945
# RevCode_Other_Imaging_Services                      0.000271    -0.000081
# payer_name                                          0.001165    -0.007257
# claim_has_referring_provider_id                     0.001643     0.002383
# payer_resp_seq_num                                 -0.001259     0.001183
# subscriber_pat_gender                              -0.008158    -0.005619
# subscriber_city                                    -0.005754    -0.004166
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.001118    -0.004150
# HCPCSCode_Surgery                                  -0.002761    -0.010767
# admission_source_code                              -0.002161    -0.004528
# admission_type_code                                 0.004126    -0.005579
# subscriber_gender                                   0.000992    -0.007104
# RevCode_Emergency_Room                             -0.004660    -0.004142
# claim_has_payer_claim_control_number                0.001314     0.001815
#
#                                                  imp_score_4  imp_score_5  \
# feat_name
# count_of_holidays                                   0.039123     0.026918
# days_taken_for_claim_filing                        -0.009977     0.003830
# total_claim_charge_amount                          -0.011161    -0.001746
# patient_age                                        -0.005064    -0.006005
# claim_creation_weekday                              0.185236     0.150673
# RevCode_Radiology_Diagnostic                       -0.009701     0.002084
# RevCode_Other_Imaging_Services                     -0.003323    -0.001924
# payer_name                                         -0.000193     0.001254
# claim_has_referring_provider_id                     0.001662     0.000367
# payer_resp_seq_num                                  0.001259    -0.000116
# subscriber_pat_gender                              -0.003284     0.003815
# subscriber_city                                    -0.009310     0.004249
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1    -0.002265    -0.000183
# HCPCSCode_Surgery                                   0.001275     0.010225
# admission_source_code                               0.003394    -0.005551
# admission_type_code                                -0.002482    -0.002310
# subscriber_gender                                   0.002277    -0.005030
# RevCode_Emergency_Room                             -0.000434     0.002170
# claim_has_payer_claim_control_number               -0.000450    -0.005532
#
#                                                  imp_score_6  imp_score_7  \
# feat_name
# count_of_holidays                                   0.045646     0.026428
# days_taken_for_claim_filing                        -0.012106    -0.011675
# total_claim_charge_amount                          -0.024071    -0.013253
# patient_age                                        -0.001500    -0.004529
# claim_creation_weekday                              0.191814     0.216088
# RevCode_Radiology_Diagnostic                       -0.002677    -0.000864
# RevCode_Other_Imaging_Services                     -0.008163    -0.000131
# payer_name                                          0.007399    -0.007859
# claim_has_referring_provider_id                     0.003869     0.001840
# payer_resp_seq_num                                 -0.005858    -0.000694
# subscriber_pat_gender                              -0.004184    -0.007568
# subscriber_city                                    -0.005320     0.005364
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1    -0.002662     0.003384
# HCPCSCode_Surgery                                  -0.007797    -0.000427
# admission_source_code                              -0.007014    -0.005719
# admission_type_code                                -0.000605    -0.000330
# subscriber_gender                                  -0.002763    -0.002767
# RevCode_Emergency_Room                             -0.014639    -0.006859
# claim_has_payer_claim_control_number                0.000594    -0.000155
#
#                                                  imp_score_8  imp_score_9
# feat_name
# count_of_holidays                                   0.056325     0.027009
# days_taken_for_claim_filing                         0.003061    -0.015312
# total_claim_charge_amount                          -0.010239    -0.002377
# patient_age                                        -0.008167    -0.010913
# claim_creation_weekday                              0.180723     0.154446
# RevCode_Radiology_Diagnostic                        0.001603    -0.000533
# RevCode_Other_Imaging_Services                      0.001243    -0.001181
# payer_name                                          0.012608    -0.000640
# claim_has_referring_provider_id                     0.002692    -0.000149
# payer_resp_seq_num                                 -0.000884    -0.000171
# subscriber_pat_gender                              -0.003553    -0.009122
# subscriber_city                                     0.012858    -0.007458
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1    -0.002145    -0.002575
# HCPCSCode_Surgery                                   0.006778    -0.013369
# admission_source_code                              -0.004118     0.000472
# admission_type_code                                -0.005794    -0.004677
# subscriber_gender                                   0.001995    -0.009324
# RevCode_Emergency_Room                             -0.006650    -0.005778
# claim_has_payer_claim_control_number               -0.000392    -0.000781
# Current Iteration#: 4
#                                                  imp_score_0  imp_score_1  \
# feat_name
# count_of_holidays                                   0.022494     0.040210
# days_taken_for_claim_filing                        -0.002262     0.010843
# patient_age                                        -0.008553    -0.003466
# claim_creation_weekday                              0.169643     0.157944
# RevCode_Radiology_Diagnostic                        0.005430     0.000768
# RevCode_Other_Imaging_Services                     -0.005618    -0.000392
# payer_name                                         -0.003065     0.002751
# claim_has_referring_provider_id                    -0.000927     0.003652
# payer_resp_seq_num                                 -0.002134     0.000934
# subscriber_pat_gender                              -0.004356    -0.006461
# subscriber_city                                    -0.001518     0.009422
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1    -0.001681    -0.001904
# HCPCSCode_Surgery                                   0.000621     0.014859
# admission_source_code                              -0.004836    -0.004317
# admission_type_code                                -0.010448     0.002404
# subscriber_gender                                  -0.000675    -0.000917
# RevCode_Emergency_Room                             -0.006549    -0.000558
# claim_has_payer_claim_control_number               -0.000717    -0.000483
#
#                                                  imp_score_2  imp_score_3  \
# feat_name
# count_of_holidays                                   0.047480     0.024312
# days_taken_for_claim_filing                        -0.004126     0.001992
# patient_age                                         0.001900    -0.009692
# claim_creation_weekday                              0.163782     0.197070
# RevCode_Radiology_Diagnostic                       -0.006531    -0.007213
# RevCode_Other_Imaging_Services                      0.001757    -0.002580
# payer_name                                          0.012728    -0.005563
# claim_has_referring_provider_id                     0.001075    -0.002157
# payer_resp_seq_num                                  0.000126     0.001767
# subscriber_pat_gender                              -0.000384    -0.004255
# subscriber_city                                    -0.003032     0.004081
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.002040    -0.002363
# HCPCSCode_Surgery                                  -0.008582    -0.019743
# admission_source_code                              -0.000498    -0.005345
# admission_type_code                                -0.003012    -0.003961
# subscriber_gender                                  -0.001871    -0.003039
# RevCode_Emergency_Room                              0.010555    -0.002616
# claim_has_payer_claim_control_number               -0.001647    -0.000584
#
#                                                  imp_score_4  imp_score_5  \
# feat_name
# count_of_holidays                                   0.041223     0.027935
# days_taken_for_claim_filing                         0.001782     0.008134
# patient_age                                        -0.000529    -0.017643
# claim_creation_weekday                              0.166523     0.139122
# RevCode_Radiology_Diagnostic                       -0.002648    -0.001486
# RevCode_Other_Imaging_Services                     -0.001026    -0.001563
# payer_name                                          0.007396     0.003096
# claim_has_referring_provider_id                    -0.000525    -0.001553
# payer_resp_seq_num                                 -0.001815     0.003444
# subscriber_pat_gender                              -0.007084    -0.003265
# subscriber_city                                    -0.005450     0.011122
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.002289    -0.000145
# HCPCSCode_Surgery                                  -0.006950     0.010953
# admission_source_code                               0.002111    -0.003405
# admission_type_code                                -0.001468     0.000135
# subscriber_gender                                  -0.008099    -0.001717
# RevCode_Emergency_Room                              0.008631    -0.009352
# claim_has_payer_claim_control_number               -0.001555    -0.000830
#
#                                                  imp_score_6  imp_score_7  \
# feat_name
# count_of_holidays                                   0.047273     0.041486
# days_taken_for_claim_filing                        -0.009278     0.012209
# patient_age                                        -0.010705    -0.006510
# claim_creation_weekday                              0.200797     0.195454
# RevCode_Radiology_Diagnostic                       -0.003374    -0.001655
# RevCode_Other_Imaging_Services                     -0.006467     0.003976
# payer_name                                          0.004349     0.003010
# claim_has_referring_provider_id                    -0.000641     0.001010
# payer_resp_seq_num                                 -0.001629    -0.000519
# subscriber_pat_gender                              -0.008100    -0.004685
# subscriber_city                                    -0.009151    -0.007097
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.000155    -0.001495
# HCPCSCode_Surgery                                  -0.011012     0.002709
# admission_source_code                              -0.005298    -0.004961
# admission_type_code                                 0.000390    -0.006568
# subscriber_gender                                  -0.000069    -0.007223
# RevCode_Emergency_Room                             -0.009941    -0.010005
# claim_has_payer_claim_control_number               -0.000095    -0.001151
#
#                                                  imp_score_8  imp_score_9
# feat_name
# count_of_holidays                                   0.070203     0.031534
# days_taken_for_claim_filing                        -0.004040    -0.000369
# patient_age                                         0.000549    -0.000232
# claim_creation_weekday                              0.188892     0.145641
# RevCode_Radiology_Diagnostic                       -0.003630    -0.002640
# RevCode_Other_Imaging_Services                      0.000469    -0.002670
# payer_name                                          0.006231     0.022580
# claim_has_referring_provider_id                     0.005188    -0.001863
# payer_resp_seq_num                                  0.001394    -0.002457
# subscriber_pat_gender                              -0.006067    -0.005687
# subscriber_city                                     0.011697    -0.001154
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1    -0.003302    -0.003439
# HCPCSCode_Surgery                                   0.004277    -0.017350
# admission_source_code                              -0.006837    -0.005074
# admission_type_code                                -0.003585    -0.000461
# subscriber_gender                                  -0.005953    -0.002335
# RevCode_Emergency_Room                             -0.003940    -0.001946
# claim_has_payer_claim_control_number                0.002355    -0.000625
# Current Iteration#: 5
#                                                  imp_score_0  imp_score_1  \
# feat_name
# count_of_holidays                                   0.034221     0.048291
# days_taken_for_claim_filing                        -0.028808    -0.001060
# claim_creation_weekday                              0.152309     0.177159
# RevCode_Radiology_Diagnostic                       -0.005587    -0.011244
# RevCode_Other_Imaging_Services                     -0.005478    -0.004814
# payer_name                                         -0.007029    -0.003327
# claim_has_referring_provider_id                    -0.004189     0.002879
# payer_resp_seq_num                                 -0.007102     0.000750
# subscriber_pat_gender                              -0.011086    -0.008516
# subscriber_city                                    -0.004876     0.007248
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1    -0.000512    -0.001499
# HCPCSCode_Surgery                                  -0.006283     0.013578
# admission_source_code                              -0.011081    -0.009127
# admission_type_code                                -0.023947    -0.004994
# subscriber_gender                                  -0.011132    -0.009410
# RevCode_Emergency_Room                             -0.002906    -0.008510
# claim_has_payer_claim_control_number               -0.003220     0.000490
#
#                                                  imp_score_2  imp_score_3  \
# feat_name
# count_of_holidays                                   0.044389     0.037872
# days_taken_for_claim_filing                        -0.024756    -0.018044
# claim_creation_weekday                              0.160479     0.184248
# RevCode_Radiology_Diagnostic                       -0.006468    -0.000137
# RevCode_Other_Imaging_Services                      0.000116    -0.001375
# payer_name                                          0.007370     0.005416
# claim_has_referring_provider_id                    -0.001004    -0.002467
# payer_resp_seq_num                                 -0.003059     0.002898
# subscriber_pat_gender                              -0.005813    -0.003260
# subscriber_city                                    -0.004456    -0.001115
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.002944     0.002473
# HCPCSCode_Surgery                                  -0.012948    -0.000368
# admission_source_code                              -0.003514    -0.006144
# admission_type_code                                -0.003387     0.006569
# subscriber_gender                                  -0.006695    -0.006706
# RevCode_Emergency_Room                             -0.006474     0.003230
# claim_has_payer_claim_control_number                0.000337     0.002550
#
#                                                  imp_score_4  imp_score_5  \
# feat_name
# count_of_holidays                                   0.062819     0.039002
# days_taken_for_claim_filing                        -0.016197     0.000832
# claim_creation_weekday                              0.184726     0.137680
# RevCode_Radiology_Diagnostic                       -0.007771     0.001729
# RevCode_Other_Imaging_Services                     -0.002084    -0.000075
# payer_name                                          0.011398     0.009101
# claim_has_referring_provider_id                    -0.002017     0.002255
# payer_resp_seq_num                                  0.003033     0.000728
# subscriber_pat_gender                               0.002682    -0.006304
# subscriber_city                                    -0.006277     0.004326
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.000061     0.001063
# HCPCSCode_Surgery                                  -0.001847     0.013382
# admission_source_code                              -0.005292    -0.008479
# admission_type_code                                -0.003096    -0.001459
# subscriber_gender                                  -0.007236    -0.005706
# RevCode_Emergency_Room                              0.001482    -0.008108
# claim_has_payer_claim_control_number               -0.000667    -0.000849
#
#                                                  imp_score_6  imp_score_7  \
# feat_name
# count_of_holidays                                   0.063175     0.022976
# days_taken_for_claim_filing                        -0.006159    -0.006850
# claim_creation_weekday                              0.160486     0.195449
# RevCode_Radiology_Diagnostic                       -0.004724     0.000697
# RevCode_Other_Imaging_Services                     -0.004696     0.001587
# payer_name                                          0.006125    -0.008199
# claim_has_referring_provider_id                     0.006161    -0.002070
# ...
# count_of_holidays                                   0.093596     0.044515
# claim_creation_weekday                              0.174155     0.137964
# RevCode_Radiology_Diagnostic                        0.004801     0.010164
# claim_has_referring_provider_id                     0.004719    -0.003533
# subscriber_city                                     0.006031    -0.006310
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.002521    -0.007822
# HCPCSCode_Surgery                                   0.009274    -0.007159
# admission_type_code                                 0.009317     0.012507
# RevCode_Emergency_Room                              0.005295    -0.005510
# claim_has_payer_claim_control_number                0.006962    -0.006772
# Current Iteration#: 13
#                                                  imp_score_0  imp_score_1  \
# feat_name
# count_of_holidays                                   0.032426     0.047168
# claim_creation_weekday                              0.109763     0.139523
# RevCode_Radiology_Diagnostic                       -0.016878    -0.007911
# claim_has_referring_provider_id                     0.000482     0.004038
# subscriber_city                                    -0.007056     0.024985
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.008951    -0.009856
# admission_type_code                                -0.011257     0.008518
# RevCode_Emergency_Room                             -0.016224     0.005418
# claim_has_payer_claim_control_number               -0.009471     0.001706
#
#                                                  imp_score_2  imp_score_3  \
# feat_name
# count_of_holidays                                   0.043418     0.043159
# claim_creation_weekday                              0.147655     0.123628
# RevCode_Radiology_Diagnostic                       -0.006791     0.010031
# claim_has_referring_provider_id                     0.000257    -0.004031
# subscriber_city                                    -0.000706     0.011210
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1    -0.007170    -0.006432
# admission_type_code                                 0.012057    -0.008509
# RevCode_Emergency_Room                              0.017089    -0.002322
# claim_has_payer_claim_control_number               -0.000008    -0.008610
#
#                                                  imp_score_4  imp_score_5  \
# feat_name
# count_of_holidays                                   0.079878     0.044985
# claim_creation_weekday                              0.144133     0.121853
# RevCode_Radiology_Diagnostic                       -0.018115     0.007358
# claim_has_referring_provider_id                    -0.001070    -0.001350
# subscriber_city                                    -0.006597     0.027308
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1    -0.011143     0.009463
# admission_type_code                                 0.016102     0.008216
# RevCode_Emergency_Room                              0.003475     0.006940
# claim_has_payer_claim_control_number                0.004276    -0.009415
#
#                                                  imp_score_6  imp_score_7  \
# feat_name
# count_of_holidays                                   0.071557     0.035348
# claim_creation_weekday                              0.152734     0.162400
# RevCode_Radiology_Diagnostic                        0.010212     0.008068
# claim_has_referring_provider_id                    -0.003831     0.004859
# subscriber_city                                     0.018953    -0.001546
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.022438     0.002265
# admission_type_code                                 0.020200    -0.008156
# RevCode_Emergency_Room                              0.004575     0.002337
# claim_has_payer_claim_control_number                0.003067     0.001371
#
#                                                  imp_score_8  imp_score_9
# feat_name
# count_of_holidays                                   0.077823     0.028445
# claim_creation_weekday                              0.152196     0.117988
# RevCode_Radiology_Diagnostic                        0.010059     0.015464
# claim_has_referring_provider_id                     0.006839    -0.004060
# subscriber_city                                     0.021205     0.009060
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.009907    -0.007886
# admission_type_code                                 0.016812     0.006306
# RevCode_Emergency_Room                             -0.000758     0.011196
# claim_has_payer_claim_control_number                0.009176    -0.004575
# Current Iteration#: 14
#                                                  imp_score_0  imp_score_1  \
# feat_name
# count_of_holidays                                   0.040204     0.044714
# claim_creation_weekday                              0.136311     0.142130
# RevCode_Radiology_Diagnostic                       -0.006457    -0.012583
# claim_has_referring_provider_id                     0.000688    -0.007250
# subscriber_city                                    -0.000631     0.015425
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.004660    -0.015792
# admission_type_code                                -0.007700     0.014340
# RevCode_Emergency_Room                             -0.007117    -0.000936
#
#                                                  imp_score_2  imp_score_3  \
# feat_name
# count_of_holidays                                   0.045203     0.036000
# claim_creation_weekday                              0.151385     0.136909
# RevCode_Radiology_Diagnostic                       -0.010437     0.009646
# claim_has_referring_provider_id                     0.001226    -0.003186
# subscriber_city                                     0.003338     0.005530
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.001243    -0.007195
# admission_type_code                                 0.007735     0.000803
# RevCode_Emergency_Room                              0.013124     0.003641
#
#                                                  imp_score_4  imp_score_5  \
# feat_name
# count_of_holidays                                   0.061431     0.040417
# claim_creation_weekday                              0.117823     0.148293
# RevCode_Radiology_Diagnostic                       -0.016801     0.016806
# claim_has_referring_provider_id                    -0.003536     0.003301
# subscriber_city                                    -0.002966     0.025256
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1    -0.002628     0.021270
# admission_type_code                                 0.010508     0.011026
# RevCode_Emergency_Room                             -0.004647     0.015043
#
#                                                  imp_score_6  imp_score_7  \
# feat_name
# count_of_holidays                                   0.066058     0.027930
# claim_creation_weekday                              0.154591     0.177786
# RevCode_Radiology_Diagnostic                        0.009058     0.013886
# claim_has_referring_provider_id                    -0.000252     0.005134
# subscriber_city                                     0.027906    -0.002359
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.014722     0.000500
# admission_type_code                                 0.019974    -0.001961
# RevCode_Emergency_Room                              0.008062    -0.004587
#
#                                                  imp_score_8  imp_score_9
# feat_name
# count_of_holidays                                   0.085140     0.026611
# claim_creation_weekday                              0.157739     0.139730
# RevCode_Radiology_Diagnostic                        0.013878     0.004331
# claim_has_referring_provider_id                     0.005427    -0.003558
# subscriber_city                                     0.004650     0.005281
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.015247    -0.010677
# admission_type_code                                 0.016857     0.018892
# RevCode_Emergency_Room                              0.000235     0.003245
# Current Iteration#: 15
#                                                  imp_score_0  imp_score_1  \
# feat_name
# count_of_holidays                                   0.030406     0.042568
# claim_creation_weekday                              0.113599     0.127287
# RevCode_Radiology_Diagnostic                       -0.005463    -0.000043
# subscriber_city                                     0.002453     0.027912
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.008763    -0.010868
# admission_type_code                                -0.002342     0.019824
# RevCode_Emergency_Room                             -0.001595     0.002481
#
#                                                  imp_score_2  imp_score_3  \
# feat_name
# count_of_holidays                                   0.036334     0.039293
# claim_creation_weekday                              0.142772     0.115377
# RevCode_Radiology_Diagnostic                       -0.017890     0.018266
# subscriber_city                                    -0.000631    -0.000636
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1    -0.008441    -0.004337
# admission_type_code                                 0.017244     0.001016
# RevCode_Emergency_Room                              0.013716     0.009384
#
#                                                  imp_score_4  imp_score_5  \
# feat_name
# count_of_holidays                                   0.076612     0.045904
# claim_creation_weekday                              0.128761     0.115274
# RevCode_Radiology_Diagnostic                       -0.014214     0.002050
# subscriber_city                                    -0.008919     0.007830
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1    -0.017385     0.015116
# admission_type_code                                 0.004225     0.005764
# RevCode_Emergency_Room                              0.003856     0.001264
#
#                                                  imp_score_6  imp_score_7  \
# feat_name
# count_of_holidays                                   0.080355     0.035702
# claim_creation_weekday                              0.157518     0.149188
# RevCode_Radiology_Diagnostic                        0.010448     0.024272
# subscriber_city                                     0.024205    -0.012542
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.009811     0.026724
# admission_type_code                                 0.021654     0.011525
# RevCode_Emergency_Room                              0.004892     0.003888
#
#                                                  imp_score_8  imp_score_9
# feat_name
# count_of_holidays                                   0.079240     0.032066
# claim_creation_weekday                              0.135109     0.119098
# RevCode_Radiology_Diagnostic                       -0.001836     0.008829
# subscriber_city                                    -0.003487     0.024547
# ccsr_category_1_code_ExternalCauseOfInjury_HI_1     0.005304    -0.005239
# admission_type_code                                 0.015083     0.012434
# RevCode_Emergency_Room                             -0.006078    -0.000046
# Current Iteration#: 16
#                               imp_score_0  imp_score_1  imp_score_2  \
# feat_name
# count_of_holidays                0.033877     0.050625     0.044426
# claim_creation_weekday           0.097537     0.133915     0.145627
# RevCode_Radiology_Diagnostic    -0.014695    -0.002239    -0.008466
# subscriber_city                 -0.000996     0.027038     0.012706
# admission_type_code             -0.002214     0.023492     0.026272
# RevCode_Emergency_Room          -0.009744     0.008353     0.012030
#
#                               imp_score_3  imp_score_4  imp_score_5  \
# feat_name
# count_of_holidays                0.047138     0.081940     0.039159
# claim_creation_weekday           0.125599     0.112906     0.108850
# RevCode_Radiology_Diagnostic     0.008461    -0.009853     0.004707
# subscriber_city                  0.004852    -0.008231     0.019478
# admission_type_code             -0.011655     0.016284     0.005257
# RevCode_Emergency_Room           0.018322     0.008726     0.003287
#
#                               imp_score_6  imp_score_7  imp_score_8  \
# feat_name
# count_of_holidays                0.063898     0.039513     0.081592
# claim_creation_weekday           0.158616     0.157642     0.134740
# RevCode_Radiology_Diagnostic    -0.004463     0.009707     0.003314
# subscriber_city                  0.015887    -0.006277    -0.007247
# admission_type_code              0.015245     0.000177     0.006901
# RevCode_Emergency_Room           0.009822     0.001813    -0.004630
#
#                               imp_score_9
# feat_name
# count_of_holidays                0.027558
# claim_creation_weekday           0.098128
# RevCode_Radiology_Diagnostic     0.007344
# subscriber_city                  0.023718
# admission_type_code              0.008235
# RevCode_Emergency_Room           0.010406
# Current Iteration#: 17
#                         imp_score_0  imp_score_1  imp_score_2  imp_score_3  \
# feat_name
# count_of_holidays          0.029156     0.059056     0.053506     0.045375
# claim_creation_weekday     0.121912     0.127261     0.131891     0.095185
# subscriber_city            0.021110     0.041911     0.009767     0.015603
# admission_type_code       -0.014836     0.011907     0.022069    -0.006503
# RevCode_Emergency_Room     0.014324     0.019979     0.025830     0.013641
#
#                         imp_score_4  imp_score_5  imp_score_6  imp_score_7  \
# feat_name
# count_of_holidays          0.077528     0.046466     0.086193     0.042028
# claim_creation_weekday     0.121330     0.099151     0.145096     0.157200
# subscriber_city            0.011812     0.029093     0.007661    -0.010151
# admission_type_code        0.025758    -0.009412     0.008342     0.017777
# RevCode_Emergency_Room     0.009711    -0.007616     0.003267     0.021333
#
#                         imp_score_8  imp_score_9
# feat_name
# count_of_holidays          0.097306     0.034644
# claim_creation_weekday     0.135833     0.122229
# subscriber_city           -0.012031     0.037229
# admission_type_code        0.003211     0.009751
# RevCode_Emergency_Room     0.014181     0.016156
# Current Iteration#: 18

# %%
pickle.dump(cfic_tracker, open("ic_rfe_output.pickle", "wb"))
